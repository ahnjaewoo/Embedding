# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr
import matplotlib.dates as mdates

# %matplotlib inline
plt.rcParams['text.latex.unicode'] = True
#plt.rcParams["font.family"] = 'Times New Roman'
#plt.rcParams["font.size"] = 18
plt.rcParams["font.size"] = 15

# %% [markdown]
# ## transE - fb15k / wn18

# %% [markdown]
# ### bar

# %%
# train_time fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([384.0926941, 226.4736139, 175.0708261, 143.78037])
fb15k_20_50 = np.array([372.4625913, 212.6754621, 166.2081116, 134.532897])
fb15k_10_100 = np.array([360.2100395, 201.1505311, 154.6948297, 117.4907523])
fb15k_baseline = np.array([665.615, 358.186, 241.745, 190.474])
fb15k_single = 355.75

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 / 100')
ax.bar(num_workers +  0.3, fb15k_baseline, width = 0.2, label = 'baseline')
ax.plot(ax.get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Training time (s)')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 700, 150))
ax.set_xlim(1, 9)
ax.set_ylim(0, 700)

plt.tight_layout()
plt.savefig('./bar_traintime_transe_fb15k.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# train_time wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([172.4139061, 122.9997569, 114.8016921, 112.1800494])
wn18_20_50 = np.array([167.2658223, 109.6806649, 102.3343716, 102.4388722])
wn18_10_100 = np.array([131.3481495, 83.29489927, 102.3343716, 72.74648517])
wn18_baseline = np.array([187.45, 111.198, 78.3144, 69.2653])
wn18_single = 104.05

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, wn18_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, wn18_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, wn18_10_100, width = 0.2, label = '10 / 100')
ax.bar(num_workers +  0.3, wn18_baseline, width = 0.2, label = 'baseline')
ax.plot(ax.get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Training time (s)')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 220, 50))
ax.set_xlim(1, 9)
ax.set_ylim(0, 220)

plt.tight_layout()
plt.savefig('./bar_traintime_transe_wn18.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# accuracy fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.975149, 0.968106, 0.962232, 0.958838]) * 100
fb15k_20_50 = np.array([0.975369, 0.966396, 0.960861, 0.958034]) * 100
fb15k_10_100 = np.array([0.972338, 0.962807, 0.956239, 0.952456]) * 100
fb15k_baseline = np.array([96.4077, 96.4001, 96.3798, 96.472])
fb15k_single = 0.98018 * 100

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 / 100')
ax.bar(num_workers +  0.3, fb15k_baseline, width = 0.2, label = 'baseline')
ax.plot(ax.get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Accuracy (%)')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 100, 1))
ax.set_xlim(1, 9)
ax.set_ylim(94.5, 98.5)

plt.tight_layout()
plt.savefig('./bar_accuracy_transe_fb15k.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# accuracy wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([0.9395, 0.9408, 0.9646, 0.9681]) * 100
wn18_20_50 = np.array([0.933, 0.9406, 0.963, 0.9675]) * 100
wn18_10_100 = np.array([0.9332, 0.9409, 0.963, 0.9607]) * 100
wn18_baseline = np.array([97.01, 96.95, 97, 97.01])
wn18_single = 0.9727 * 100

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, wn18_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, wn18_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, wn18_10_100, width = 0.2, label = '10 / 100')
ax.bar(num_workers +  0.3, wn18_baseline, width = 0.2, label = 'baseline')
ax.plot(ax.get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Accuracy (%)')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 100, 1))
ax.set_xlim(1, 9)
ax.set_ylim(92.5, 98.5)

plt.tight_layout()
plt.savefig('./bar_accuracy_transe_wn18.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# BestHITS fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.612314, 0.607202, 0.601615, 0.587293]) * 100
fb15k_20_50 = np.array([0.611484, 0.602698, 0.598009, 0.588123]) * 100
fb15k_10_100 = np.array([0.601683, 0.586836, 0.587192, 0.574546]) * 100
fb15k_baseline = np.array([45.3124, 45.4817, 45.1601, 45.5807])
fb15k_single = 0.6062 * 100

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 / 100')
ax.bar(num_workers +  0.3, fb15k_baseline, width = 0.2, label = 'baseline')
ax.plot(ax.get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestHITS (%)')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 100, 5))
ax.set_xlim(1, 9)
ax.set_ylim(42, 63)

plt.tight_layout()
plt.savefig('./bar_besthit_transe_fb15k.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# BestHITS wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([0.607, 0.691, 0.8804, 0.8914]) * 100
wn18_20_50 = np.array([0.5732, 0.6736, 0.8772, 0.8802]) * 100
wn18_10_100 = np.array([0.5352, 0.6532, 0.8772, 0.8436]) * 100
wn18_baseline = np.array([84.48, 84.57, 84.97, 83.99])
wn18_single = 0.91341 * 100

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, wn18_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, wn18_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, wn18_10_100, width = 0.2, label = '10 / 100')
ax.bar(num_workers +  0.3, wn18_baseline, width = 0.2, label = 'baseline')
ax.plot(ax.get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestHITS (%)')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 100, 5))
ax.set_xlim(1, 9)
ax.set_ylim(50, 93)

plt.tight_layout()
plt.savefig('./bar_besthit_transe_wn18.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# BestMRR fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.388425, 0.385677, 0.385634, 0.37842])
fb15k_20_50 = np.array([0.385619, 0.384245, 0.385434, 0.382408])
fb15k_10_100 = np.array([0.374555, 0.370558, 0.378761, 0.37069])
fb15k_baseline = np.array([0.241504, 0.244103, 0.241382, 0.244395])
fb15k_single = 0.3793

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 / 100')
ax.bar(num_workers +  0.3, fb15k_baseline, width = 0.2, label = 'baseline')
ax.plot(ax.get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestMRR')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 0.41, 0.05))
ax.set_xlim(1, 9)
ax.set_ylim(0.2, 0.41)

plt.tight_layout()
plt.savefig('./bar_bestmrr_transe_fb15k.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# BestMRR wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([0.407367, 0.497096, 0.490939, 0.505489])
wn18_20_50 = np.array([0.374965, 0.495152, 0.482725, 0.490374])
wn18_10_100 = np.array([0.326287, 0.502528, 0.482725, 0.453048])
wn18_baseline = np.array([0.350128, 0.347224, 0.348321, 0.341686])
wn18_single = 0.45581

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, wn18_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, wn18_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, wn18_10_100, width = 0.2, label = '10 / 100')
ax.bar(num_workers +  0.3, wn18_baseline, width = 0.2, label = 'baseline')
ax.plot(ax.get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestMRR')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 1, 0.05))
ax.set_xlim(1, 9)
ax.set_ylim(0.25, 0.53)

plt.tight_layout()
plt.savefig('./bar_bestmrr_transe_wn18.pdf', dpi = 300, quality = 100)
plt.show()

# %% [markdown]
# ## transG - fb15k / wn18

# %% [markdown]
# ### bar

# %%
# train_time fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([2427.172586, 1281.726792, 1400.069755, 734.1884628])
fb15k_20_50 = np.array([2425.180953, 1299.76457, 918.1491997, 734.1884628])
fb15k_10_100 = np.array([2627.507176, 1400.069755, 953.8609892, 774.2193177])
fb15k_single = 2582.96

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 / 100')
ax.plot(ax.get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Training time (s)')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 3000, 300))
ax.set_xlim(1, 9)
ax.set_ylim(550, 2750)

plt.tight_layout()
plt.savefig('./bar_traintime_transg_fb15k.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# train_time wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([837.6908211, 509.1723687, 423.2576023, 339.2227609])
wn18_20_50 = np.array([897.5952471, 493.7025131, 398.7861522, 376.4033913])
wn18_10_100 = np.array([862.224112, 478.5678193, 402.2448581, 385.7693237])
wn18_single = 872.32

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, wn18_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, wn18_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, wn18_10_100, width = 0.2, label = '10 / 100')
ax.plot(ax.get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Training time (s)')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 950, 150))
ax.set_xlim(1, 9)
ax.set_ylim(250, 950)

plt.tight_layout()
plt.savefig('./bar_traintime_transg_wn18.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# accuracy fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.97597, 0.969604, 0.965135, 0.960844]) * 100
fb15k_20_50 = np.array([0.975504, 0.968766, 0.962943, 0.960844]) * 100
fb15k_10_100 = np.array([0.972795, 0.965135, 0.960014, 0.955731]) * 100
fb15k_single = 0.98084 * 100

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 / 100')
ax.bar(num_workers +  0.3, fb15k_baseline, width = 0.2, label = 'baseline')
ax.plot(ax.get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Accuracy (%)')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 100, 1))
ax.set_xlim(1, 9)
ax.set_ylim(95, 98.5)

plt.tight_layout()
plt.savefig('./bar_accuracy_transg_fb15k.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# accuracy wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([0.9735, 0.971, 0.9694, 0.9689]) * 100
wn18_20_50 = np.array([0.973, 0.9678, 0.9689, 0.9676]) * 100
wn18_10_100 = np.array([0.9695, 0.9695, 0.9654, 0.9652]) * 100
wn18_single = 0.9787 * 100

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, wn18_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, wn18_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, wn18_10_100, width = 0.2, label = '10 / 100')
ax.bar(num_workers +  0.3, wn18_baseline, width = 0.2, label = 'baseline')
ax.plot(ax.get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Accuracy (%)')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 100, 0.5))
ax.set_xlim(1, 9)
ax.set_ylim(96.2, 98.2)

plt.tight_layout()
plt.savefig('./bar_accuracy_transg_wn18.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# BestHITS fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.616512, 0.605661, 0.588783, 0.595605]) * 100
fb15k_20_50 = np.array([0.615107, 0.603376, 0.601784, 0.595605]) * 100
fb15k_10_100 = np.array([0.594793, 0.588783, 0.586007, 0.575409]) * 100
fb15k_single = 0.6026 * 100

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 / 100')
ax.plot(ax.get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestHITS (%)')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 100, 1))
ax.set_xlim(1, 9)
ax.set_ylim(56.5, 62.5)

plt.tight_layout()
plt.savefig('./bar_besthit_transg_fb15k.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# BestHITS wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([0.9184, 0.9126, 0.9044, 0.9012]) * 100
wn18_20_50 = np.array([0.906, 0.8954, 0.9084, 0.8938]) * 100
wn18_10_100 = np.array([0.895, 0.8958, 0.8912, 0.886]) * 100
wn18_single = 0.92081 * 100

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, wn18_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, wn18_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, wn18_10_100, width = 0.2, label = '10 / 100')
ax.plot(ax.get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestHITS (%)')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 100, 1))
ax.set_xlim(1, 9)
ax.set_ylim(87.5, 92.5)

plt.tight_layout()
plt.savefig('./bar_besthit_transg_wn18.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# BestMRR fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.261467, 0.25228, 0.248199, 0.246904])
fb15k_20_50 = np.array([0.258235, 0.25523, 0.253999, 0.246904])
fb15k_10_100 = np.array([0.255534, 0.248199, 0.250757, 0.240789])
fb15k_single = 0.37818

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 / 100')
ax.plot(ax.get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestMRR')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 0.41, 0.05))
ax.set_xlim(1, 9)
ax.set_ylim(0.2, 0.40)

plt.tight_layout()
plt.savefig('./bar_bestmrr_transg_fb15k.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# BestMRR wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([0.362662, 0.350539, 0.381873, 0.357697])
wn18_20_50 = np.array([0.402233, 0.384905, 0.3459, 0.365515])
wn18_10_100 = np.array([0.460113, 0.452441, 0.397461, 0.422256])
wn18_single = 0.51419

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, wn18_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, wn18_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, wn18_10_100, width = 0.2, label = '10 / 100')
ax.plot(ax.get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestMRR')
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 1, 0.05))
ax.set_xlim(1, 9)
ax.set_ylim(0.31, 0.53)

plt.tight_layout()
plt.savefig('./bar_bestmrr_transg_wn18.pdf', dpi = 300, quality = 100)
plt.show()

# %% [markdown]
# ## transE - dbpedia

# %% [markdown]
# ### bar
