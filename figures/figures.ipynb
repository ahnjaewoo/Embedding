# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr
import matplotlib.dates as mdates

# %matplotlib inline
plt.rcParams['text.latex.unicode'] = True
#plt.rcParams["font.family"] = 'Times New Roman'
#plt.rcParams["font.size"] = 18
plt.rcParams["font.size"] = 15

# %% [markdown]
# ## transE - fb15k / wn18

# %% [markdown]
# ### bar

# %%
# train_time
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([384.0926941, 226.4736139, 175.0708261, 143.78037])
fb15k_20_50 = np.array([372.4625913, 212.6754621, 166.2081116, 134.532897])
fb15k_10_100 = np.array([360.2100395, 201.1505311, 154.6948297, 117.4907523])
fb15k_baseline = np.array([665.615, 358.186, 241.745, 190.474])
fb15k_single = 355.75

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 / 40')
ax.bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 / 50')
ax.bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 / 100')
ax.bar(num_workers +  0.3, fb15k_baseline, width = 0.2, label = 'baseline')
ax.plot(ax.get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
#ax.set_title('fb15k train_time')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Training time')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), fancybox=True, ncol=5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 700, 150))
ax.set_xlim(1, 9)
ax.set_ylim(0, 700)

plt.tight_layout()
plt.savefig('./bar_accuracy_transe_fb15k.png', dpi = 300, quality = 100)
plt.show()

# %%
# train_time
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([172.4139061, 122.9997569, 114.8016921, 112.1800494])
wn18_20_50 = np.array([167.2658223, 109.6806649, 102.3343716, 102.4388722])
wn18_10_100 = np.array([131.3481495, 83.29489927, 102.3343716, 72.74648517])
wn18_baseline = np.array([187.45, 111.198, 78.3144, 69.2653])
wn18_single = 104.05

fig, ax = plt.subplots(1, 1, figsize = (10, 6))

ax.bar(num_workers - 0.3, wn18_25_40, width = 0.2, label = '25 * 40')
ax.bar(num_workers - 0.1, wn18_20_50, width = 0.2, label = '10 * 50')
ax.bar(num_workers + 0.1, wn18_10_100, width = 0.2, label = '10 * 100')
ax.bar(num_workers +  0.3, wn18_baseline, width = 0.2, label = 'baseline')
ax.plot(ax.get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
#ax.set_title('wn18 train_time')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Training time')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), fancybox=True, ncol=5)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 225, 50))
ax.set_xlim(1, 9)
ax.set_ylim(0, 225)

plt.tight_layout()
#plt.savefig('./bar_accuracy_wn18.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# accuracy
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.975149, 0.968106, 0.962232, 0.958838]) * 100
fb15k_20_50 = np.array([0.975369, 0.966396, 0.960861, 0.958034]) * 100
fb15k_10_100 = np.array([0.972338, 0.962807, 0.956239, 0.952456]) * 100
fb15k_baseline = np.array([96.4077, 96.4001, 96.3798, 96.472])
fb15k_single = 0.98018 * 100

wn18_25_40 = np.array([0.9395, 0.9408, 0.9646, 0.9681]) * 100
wn18_20_50 = np.array([0.933, 0.9406, 0.963, 0.9675]) * 100
wn18_10_100 = np.array([0.9332, 0.9409, 0.963, 0.9607]) * 100
wn18_baseline = np.array([97.01, 96.95, 97, 97.01])
wn18_single = 0.9727 * 100

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 * 40')
ax[0].bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 * 50')
ax[0].bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 * 100')
ax[0].bar(num_workers +  0.3, fb15k_baseline, width = 0.2, label = 'baseline')
ax[0].plot(ax[0].get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
#ax[0].set_title('fb15k accuracy')
ax[0].set_ylabel('accuracy (%)')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
ax[0].set_yticks(np.arange(95, 98.5, 0.5))
ax[0].set_xlim(1, 9)
ax[0].set_ylim(95, 98.5)

ax[1].bar(num_workers - 0.3, wn18_25_40, width = 0.2, label = '25 * 40')
ax[1].bar(num_workers - 0.1, wn18_20_50, width = 0.2, label = '10 * 50')
ax[1].bar(num_workers + 0.1, wn18_10_100, width = 0.2, label = '10 * 100')
ax[1].bar(num_workers +  0.3, wn18_baseline, width = 0.2, label = 'baseline')
ax[1].plot(ax[1].get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
#ax[1].set_title('wn18 accuracy')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('accuracy (%)')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
ax[1].set_yticks(np.arange(93, 98, 0.5))
ax[1].set_xlim(1, 9)
ax[1].set_ylim(93, 98)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# Filter.BestHITS
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.612314, 0.607202, 0.601615, 0.587293]) * 100
fb15k_20_50 = np.array([0.611484, 0.602698, 0.598009, 0.588123]) * 100
fb15k_10_100 = np.array([0.601683, 0.586836, 0.587192, 0.574546]) * 100
fb15k_baseline = np.array([45.3124, 45.4817, 45.1601, 45.5807])
fb15k_single = 0.6062 * 100

wn18_25_40 = np.array([0.607, 0.691, 0.8804, 0.8914]) * 100
wn18_20_50 = np.array([0.5732, 0.6736, 0.8772, 0.8802]) * 100
wn18_10_100 = np.array([0.5352, 0.6532, 0.8772, 0.8436]) * 100
wn18_baseline = np.array([84.48, 84.57, 84.97, 83.99])
wn18_single = 0.91341 * 100

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 * 40')
ax[0].bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 * 50')
ax[0].bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 * 100')
ax[0].bar(num_workers +  0.3, fb15k_baseline, width = 0.2, label = 'baseline')
ax[0].plot(ax[0].get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
#ax[0].set_title('fb15k Filter.BestHITS')
ax[0].set_ylabel('Filter.BestHITS (%)')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
ax[0].set_yticks(np.arange(40, 62.0, 3))
ax[0].set_xlim(1, 9)
ax[0].set_ylim(43, 62.0)

ax[1].bar(num_workers - 0.3, wn18_25_40, width = 0.2, label = '25 * 40')
ax[1].bar(num_workers - 0.1, wn18_20_50, width = 0.2, label = '10 * 50')
ax[1].bar(num_workers + 0.1, wn18_10_100, width = 0.2, label = '10 * 100')
ax[1].bar(num_workers +  0.3, wn18_baseline, width = 0.2, label = 'baseline')
ax[1].plot(ax[1].get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
#ax[1].set_title('wn18 Filter.BestHITS')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('Filter.BestHITS (%)')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
ax[1].set_yticks(np.arange(50, 94, 5))
ax[1].set_xlim(1, 9)
ax[1].set_ylim(50, 94)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()

# %% [markdown]
# ### line

# %%
# accuracy
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.975149, 0.968106, 0.962232, 0.958838]) * 100
fb15k_20_50 = np.array([0.975369, 0.966396, 0.960861, 0.958034]) * 100
fb15k_10_100 = np.array([0.972338, 0.962807, 0.956239, 0.952456]) * 100
fb15k_baseline = np.array([96.4077, 96.4001, 96.3798, 96.472])
fb15k_single = 0.98018 * 100

wn18_25_40 = np.array([0.9395, 0.9408, 0.9646, 0.9681]) * 100
wn18_20_50 = np.array([0.933, 0.9406, 0.963, 0.9675]) * 100
wn18_10_100 = np.array([0.9332, 0.9409, 0.963, 0.9607]) * 100
wn18_baseline = np.array([97.01, 96.95, 97, 97.01])
wn18_single = 0.9727 * 100

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].plot(num_workers, fb15k_25_40, lw = 4, label = '25 * 40')
ax[0].plot(num_workers, fb15k_20_50, lw = 4, label = '10 * 50')
ax[0].plot(num_workers, fb15k_10_100, lw = 4, label = '10 * 100')
ax[0].plot(num_workers, fb15k_baseline, lw = 4, label = 'baseline')
ax[0].plot(ax[0].get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
#ax[0].set_title('fb15k accuracy')
ax[0].set_ylabel('accuracy (%)')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
ax[0].set_yticks(np.arange(95, 98.5, 0.5))
ax[0].set_xlim(1, 9)
ax[0].set_ylim(95, 98.5)

ax[1].plot(num_workers, wn18_25_40, lw = 4, label = '25 * 40')
ax[1].plot(num_workers, wn18_20_50, lw = 4, label = '10 * 50')
ax[1].plot(num_workers, wn18_10_100, lw = 4, label = '10 * 100')
ax[1].plot(num_workers, wn18_baseline, lw = 4, label = 'baseline')
ax[1].plot(ax[1].get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
#ax[1].set_title('wn18 accuracy')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('accuracy (%)')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
ax[1].set_yticks(np.arange(93, 98, 0.5))
ax[1].set_xlim(1, 9)
ax[1].set_ylim(93, 98)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# Filter.BestHITS
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.612314, 0.607202, 0.601615, 0.587293]) * 100
fb15k_20_50 = np.array([0.611484, 0.602698, 0.598009, 0.588123]) * 100
fb15k_10_100 = np.array([0.601683, 0.586836, 0.587192, 0.574546]) * 100
fb15k_baseline = np.array([45.3124, 45.4817, 45.1601, 45.5807])
fb15k_single = 0.6062 * 100

wn18_25_40 = np.array([0.607, 0.691, 0.8804, 0.8914]) * 100
wn18_20_50 = np.array([0.5732, 0.6736, 0.8772, 0.8802]) * 100
wn18_10_100 = np.array([0.5352, 0.6532, 0.8772, 0.8436]) * 100
wn18_baseline = np.array([84.48, 84.57, 84.97, 83.99])
wn18_single = 0.91341 * 100

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].plot(num_workers, fb15k_25_40, lw = 4, label = '25 * 40')
ax[0].plot(num_workers, fb15k_20_50, lw = 4, label = '10 * 50')
ax[0].plot(num_workers, fb15k_10_100, lw = 4, label = '10 * 100')
ax[0].plot(num_workers, fb15k_baseline, lw = 4, label = 'baseline')
ax[0].plot(ax[0].get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
#ax[0].set_title('fb15k Filter.BestHITS')
ax[0].set_ylabel('Filter.BestHITS (%)')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
ax[0].set_yticks(np.arange(40, 62.0, 3))
ax[0].set_xlim(1, 9)
ax[0].set_ylim(43, 62.0)

ax[1].plot(num_workers, wn18_25_40, lw = 4, label = '25 * 40')
ax[1].plot(num_workers, wn18_20_50, lw = 4, label = '10 * 50')
ax[1].plot(num_workers, wn18_10_100, lw = 4, label = '10 * 100')
ax[1].plot(num_workers, wn18_baseline, lw = 4, label = 'baseline')
ax[1].plot(ax[1].get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
#ax[1].set_title('wn18 Filter.BestHITS')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('Filter.BestHITS (%)')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
ax[1].set_yticks(np.arange(50, 94, 5))
ax[1].set_xlim(1, 9)
ax[1].set_ylim(50, 94)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()

# %% [markdown]
# ### stacked bar

# %%
# train_time (stacked)
num_workers = np.array([2, 4, 6, 8])

# worker_time = datamodel + sock_load + embedding + sock_save + redis
fb15k_25_40_datamodel = np.array([0.4060816795, 0.360183787, 0.2352776781, 0.1863757008])
fb15k_25_40_sock_load = np.array([0.2405896661, 0.2899126091, 0.2185789993, 0.2066386069])
fb15k_25_40_embedding = np.array([12.92596185, 6.840657786, 4.633318555, 3.540071822])
fb15k_25_40_sock_save = np.array([0.06097859027, 0.03347889958, 0.02252404364, 0.01740762649])
fb15k_25_40_redis = np.array([0.414518496, 0.3771114045, 0.4069293373, 0.44777168])

fb15k_20_50_datamodel = np.array([0.4012939102, 0.3451078375, 0.2282792481, 0.1956193881])
fb15k_20_50_sock_load = np.array([0.2513509047, 0.2161924486, 0.2295260321, 0.2244095588])
fb15k_20_50_embedding = np.array([16.00759678, 8.441847484, 5.813689788, 4.524871064])
fb15k_20_50_sock_save = np.array([0.05808895617, 0.03091666531, 0.02218456432, 0.01671374746])
fb15k_20_50_redis = np.array([0.4059131121, 0.411809946, 0.4097434354, 0.4398306205])

fb15k_10_100_datamodel = np.array([0.4042115191, 0.365170745, 0.241313037, 0.1760569743])
fb15k_10_100_sock_load = np.array([0.2232273517, 0.2182821115, 0.6268147103, 0.2072079304])
fb15k_10_100_embedding = np.array([32.81362344, 17.07111001, 11.79367663, 9.012971793])
fb15k_10_100_sock_save = np.array([0.05873357912, 0.03094665613, 0.02232789365, 0.01712605406])
fb15k_10_100_redis = np.array([0.453395141, 0.3655905137, 0.377968167, 0.4881255375])

#fb15k_baseline = np.array([665.615, 358.186, 241.745, 190.474])
#fb15k_single = 355.75

wn18_25_40_datamodel = np.array([0.1123157293, 0.04773566315, 0.03423215721, 0.02677469097])
wn18_25_40_sock_load = np.array([0.5016988484, 0.3675140954, 0.3309959025, 0.3235389998])
wn18_25_40_embedding = np.array([4.448923911, 2.454985835, 1.726381669, 1.32908388])
wn18_25_40_sock_save = np.array([0.1188276266, 0.06973710077, 0.05401794852, 0.03845330482])
wn18_25_40_redis = np.array([0.7960590434, 0.8591642303, 0.9367045539, 1.035690073])

wn18_20_50_datamodel = np.array([0.1086107526, 0.04944754535, 0.03607269938, 0.02684834436])
wn18_20_50_sock_load = np.array([0.5489070632, 0.3550188833, 0.3314103793, 0.5052759536])
wn18_20_50_embedding = np.array([5.679536947, 3.037282617, 2.111264956, 1.651478203])
wn18_20_50_sock_save = np.array([0.1108346349, 0.06771114598, 0.05246685797, 0.03713868701])
wn18_20_50_redis = np.array([0.8341528911, 0.8657487317, 0.9576306133, 1.07454585])

wn18_10_100_datamodel = np.array([0.11895635, 0.05168515946, 0.03607269938, 0.02599296439])
wn18_10_100_sock_load = np.array([0.5231010437, 0.366637743, 0.3314103793, 0.322489885])
wn18_10_100_embedding = np.array([10.16025601, 5.700393152, 2.111264956, 3.005548298])
wn18_10_100_sock_save = np.array([0.1116531639, 0.06562940829, 0.05246685797, 0.03533489335])
wn18_10_100_redis = np.array([0.8463362419, 0.8948526604, 0.9576306133, 1.101782201])

#wn18_baseline = np.array([187.45, 111.198, 78.3144, 69.2653])
#wn18_single = 104.05

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].bar(num_workers - 0.2, fb15k_25_40_datamodel, width = 0.2, label = '25 * 40 datamodel')
ax[0].bar(num_workers - 0.2, fb15k_25_40_sock_load, width = 0.2, label = '25 * 40 sock_load',
         bottom = fb15k_25_40_datamodel)
ax[0].bar(num_workers - 0.2, fb15k_25_40_embedding, width = 0.2, label = '25 * 40 embedding',
         bottom = fb15k_25_40_datamodel + fb15k_25_40_sock_load)
ax[0].bar(num_workers - 0.2, fb15k_25_40_sock_save, width = 0.2, label = '25 * 40 sock_save',
         bottom = fb15k_25_40_datamodel + fb15k_25_40_sock_load + fb15k_25_40_embedding)
ax[0].bar(num_workers - 0.2, fb15k_25_40_redis, width = 0.2, label = '25 * 40 redis',
         bottom = fb15k_25_40_datamodel + fb15k_25_40_sock_load + fb15k_25_40_embedding + fb15k_25_40_sock_save)

ax[0].bar(num_workers, fb15k_20_50_datamodel, width = 0.2, label = '20 * 50 datamodel')
ax[0].bar(num_workers, fb15k_20_50_sock_load, width = 0.2, label = '20 * 50 sock_load',
         bottom = fb15k_20_50_datamodel)
ax[0].bar(num_workers, fb15k_20_50_embedding, width = 0.2, label = '20 * 50 embedding',
         bottom = fb15k_20_50_datamodel + fb15k_20_50_sock_load)
ax[0].bar(num_workers, fb15k_20_50_sock_save, width = 0.2, label = '20 * 50 sock_save',
         bottom = fb15k_20_50_datamodel + fb15k_20_50_sock_load + fb15k_20_50_embedding)
ax[0].bar(num_workers, fb15k_20_50_redis, width = 0.2, label = '20 * 50 redis',
         bottom = fb15k_20_50_datamodel + fb15k_20_50_sock_load + fb15k_20_50_embedding + fb15k_20_50_sock_save)

ax[0].bar(num_workers + 0.2, fb15k_10_100_datamodel, width = 0.2, label = '10 * 100 datamodel')
ax[0].bar(num_workers + 0.2, fb15k_10_100_sock_load, width = 0.2, label = '10 * 100 sock_load',
         bottom = fb15k_10_100_datamodel)
ax[0].bar(num_workers + 0.2, fb15k_10_100_embedding, width = 0.2, label = '10 * 100 embedding',
         bottom = fb15k_10_100_datamodel + fb15k_10_100_sock_load)
ax[0].bar(num_workers + 0.2, fb15k_10_100_sock_save, width = 0.2, label = '10 * 100 sock_save',
         bottom = fb15k_10_100_datamodel + fb15k_10_100_sock_load + fb15k_10_100_embedding)
ax[0].bar(num_workers + 0.2, fb15k_10_100_redis, width = 0.2, label = '10 * 100 redis',
         bottom = fb15k_10_100_datamodel + fb15k_10_100_sock_load + fb15k_10_100_embedding + fb15k_10_100_sock_save)
ax[0].set_title('fb15k train_time (stacked)')
ax[0].set_ylabel('train_time')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
ax[0].set_yticks(np.arange(0, 36, 4))
ax[0].set_xlim(1, 9)
ax[0].set_ylim(0, 36)

ax[1].bar(num_workers - 0.2, wn18_25_40_datamodel, width = 0.2, label = '25 * 40 datamodel')
ax[1].bar(num_workers - 0.2, wn18_25_40_sock_load, width = 0.2, label = '25 * 40 sock_load',
         bottom = wn18_25_40_datamodel)
ax[1].bar(num_workers - 0.2, wn18_25_40_embedding, width = 0.2, label = '25 * 40 embedding',
         bottom = wn18_25_40_datamodel + wn18_25_40_sock_load)
ax[1].bar(num_workers - 0.2, wn18_25_40_sock_save, width = 0.2, label = '25 * 40 sock_save',
         bottom = wn18_25_40_datamodel + wn18_25_40_sock_load + wn18_25_40_embedding)
ax[1].bar(num_workers - 0.2, wn18_25_40_redis, width = 0.2, label = '25 * 40 redis',
         bottom = wn18_25_40_datamodel + wn18_25_40_sock_load + wn18_25_40_embedding + wn18_25_40_sock_save)

ax[1].bar(num_workers, wn18_20_50_datamodel, width = 0.2, label = '20 * 50 datamodel')
ax[1].bar(num_workers, wn18_20_50_sock_load, width = 0.2, label = '20 * 50 sock_load',
         bottom = wn18_20_50_datamodel)
ax[1].bar(num_workers, wn18_20_50_embedding, width = 0.2, label = '20 * 50 embedding',
         bottom = wn18_20_50_datamodel + wn18_20_50_sock_load)
ax[1].bar(num_workers, wn18_20_50_sock_save, width = 0.2, label = '20 * 50 sock_save',
         bottom = wn18_20_50_datamodel + wn18_20_50_sock_load + wn18_20_50_embedding)
ax[1].bar(num_workers, wn18_20_50_redis, width = 0.2, label = '20 * 50 redis',
         bottom = wn18_20_50_datamodel + wn18_20_50_sock_load + wn18_20_50_embedding + wn18_20_50_sock_save)

ax[1].bar(num_workers + 0.2, wn18_10_100_datamodel, width = 0.2, label = '10 * 100 datamodel')
ax[1].bar(num_workers + 0.2, wn18_10_100_sock_load, width = 0.2, label = '10 * 100 sock_load',
         bottom = wn18_10_100_datamodel)
ax[1].bar(num_workers + 0.2, wn18_10_100_embedding, width = 0.2, label = '10 * 100 embedding',
         bottom = wn18_10_100_datamodel + wn18_10_100_sock_load)
ax[1].bar(num_workers + 0.2, wn18_10_100_sock_save, width = 0.2, label = '10 * 100 sock_save',
         bottom = wn18_10_100_datamodel + wn18_10_100_sock_load + wn18_10_100_embedding)
ax[1].bar(num_workers + 0.2, wn18_10_100_redis, width = 0.2, label = '10 * 100 redis',
         bottom = wn18_10_100_datamodel + wn18_10_100_sock_load + wn18_10_100_embedding + wn18_10_100_sock_save)
ax[1].set_title('wn18 train_time')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('train_time')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
ax[1].set_yticks(np.arange(0, 13, 3))
ax[1].set_xlim(1, 9)
ax[1].set_ylim(0, 13)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()

# %% [markdown]
# ## transG - fb15k / wn18

# %% [markdown]
# ### bar

# %%
# train_time
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([2427.172586, 1281.726792, 1400.069755, 734.1884628])
fb15k_20_50 = np.array([2425.180953, 1299.76457, 918.1491997, 734.1884628])
fb15k_10_100 = np.array([2627.507176, 1400.069755, 953.8609892, 774.2193177])
fb15k_single = 2582.96

wn18_25_40 = np.array([837.6908211, 509.1723687, 423.2576023, 339.2227609])
wn18_20_50 = np.array([897.5952471, 493.7025131, 398.7861522, 376.4033913])
wn18_10_100 = np.array([862.224112, 478.5678193, 402.2448581, 385.7693237])
wn18_single = 872.32

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].bar(num_workers - 0.2, fb15k_25_40, width = 0.2, label = '25 * 40')
ax[0].bar(num_workers, fb15k_20_50, width = 0.2, label = '10 * 50')
ax[0].bar(num_workers + 0.2, fb15k_10_100, width = 0.2, label = '10 * 100')
ax[0].plot(ax[0].get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax[0].set_title('fb15k train_time')
ax[0].set_ylabel('train_time')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
ax[0].set_yticks(np.arange(0, 2700, 300))
ax[0].set_xlim(1, 9)
ax[0].set_ylim(0, 2700)

ax[1].bar(num_workers - 0.2, wn18_25_40, width = 0.2, label = '25 * 40')
ax[1].bar(num_workers, wn18_20_50, width = 0.2, label = '10 * 50')
ax[1].bar(num_workers + 0.2, wn18_10_100, width = 0.2, label = '10 * 100')
ax[1].plot(ax[1].get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax[1].set_title('wn18 train_time')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('train_time')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
ax[1].set_yticks(np.arange(0, 950, 100))
ax[1].set_xlim(1, 9)
ax[1].set_ylim(0, 950)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# accuracy
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.97597, 0.969604, 0.965135, 0.960844]) * 100
fb15k_20_50 = np.array([0.975504, 0.968766, 0.962943, 0.960844]) * 100
fb15k_10_100 = np.array([0.972795, 0.965135, 0.960014, 0.955731]) * 100
fb15k_single = 0.98084 * 100

wn18_25_40 = np.array([0.9735, 0.971, 0.9694, 0.9689]) * 100
wn18_20_50 = np.array([0.973, 0.9678, 0.9689, 0.9676]) * 100
wn18_10_100 = np.array([0.9695, 0.9695, 0.9654, 0.9652]) * 100
wn18_single = 0.9787 * 100

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].bar(num_workers - 0.2, fb15k_25_40, width = 0.2, label = '25 * 40')
ax[0].bar(num_workers, fb15k_20_50, width = 0.2, label = '10 * 50')
ax[0].bar(num_workers + 0.2, fb15k_10_100, width = 0.2, label = '10 * 100')
ax[0].plot(ax[0].get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax[0].set_title('fb15k accuracy')
ax[0].set_ylabel('accuracy (%)')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
ax[0].set_yticks(np.arange(95, 98.5, 0.5))
ax[0].set_xlim(1, 9)
ax[0].set_ylim(95, 98.5)

ax[1].bar(num_workers - 0.2, wn18_25_40, width = 0.2, label = '25 * 40')
ax[1].bar(num_workers, wn18_20_50, width = 0.2, label = '10 * 50')
ax[1].bar(num_workers + 0.2, wn18_10_100, width = 0.2, label = '10 * 100')
ax[1].plot(ax[1].get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax[1].set_title('wn18 accuracy')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('accuracy (%)')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
ax[1].set_yticks(np.arange(96, 98, 0.5))
ax[1].set_xlim(1, 9)
ax[1].set_ylim(96, 98)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# Filter.BestHITS
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.616512, 0.605661, 0.588783, 0.595605]) * 100
fb15k_20_50 = np.array([0.615107, 0.603376, 0.601784, 0.595605]) * 100
fb15k_10_100 = np.array([0.594793, 0.588783, 0.586007, 0.575409]) * 100
fb15k_single = 0.6026 * 100

wn18_25_40 = np.array([0.9184, 0.9126, 0.9044, 0.9012]) * 100
wn18_20_50 = np.array([0.906, 0.8954, 0.9084, 0.8938]) * 100
wn18_10_100 = np.array([0.895, 0.8958, 0.8912, 0.886]) * 100
wn18_single = 0.92081 * 100

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].bar(num_workers - 0.2, fb15k_25_40, width = 0.2, label = '25 * 40')
ax[0].bar(num_workers, fb15k_20_50, width = 0.2, label = '10 * 50')
ax[0].bar(num_workers + 0.2, fb15k_10_100, width = 0.2, label = '10 * 100')
ax[0].plot(ax[0].get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax[0].set_title('fb15k Filter.BestHITS')
ax[0].set_ylabel('Filter.BestHITS (%)')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
ax[0].set_yticks(np.arange(57, 62.0, 1))
ax[0].set_xlim(1, 9)
ax[0].set_ylim(57, 62.0)

ax[1].bar(num_workers - 0.2, wn18_25_40, width = 0.2, label = '25 * 40')
ax[1].bar(num_workers, wn18_20_50, width = 0.2, label = '10 * 50')
ax[1].bar(num_workers + 0.2, wn18_10_100, width = 0.2, label = '10 * 100')
ax[1].plot(ax[1].get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax[1].set_title('wn18 Filter.BestHITS')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('Filter.BestHITS (%)')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
ax[1].set_yticks(np.arange(88, 93, 1))
ax[1].set_xlim(1, 9)
ax[1].set_ylim(88, 93)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()

# %% [markdown]
# ### line

# %%
# accuracy
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.97597, 0.969604, 0.965135, 0.960844]) * 100
fb15k_20_50 = np.array([0.975504, 0.968766, 0.962943, 0.960844]) * 100
fb15k_10_100 = np.array([0.972795, 0.965135, 0.960014, 0.955731]) * 100
fb15k_single = 0.98084 * 100

wn18_25_40 = np.array([0.9735, 0.971, 0.9694, 0.9689]) * 100
wn18_20_50 = np.array([0.973, 0.9678, 0.9689, 0.9676]) * 100
wn18_10_100 = np.array([0.9695, 0.9695, 0.9654, 0.9652]) * 100
wn18_single = 0.9787 * 100

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].plot(num_workers, fb15k_25_40, lw = 4, label = '25 * 40')
ax[0].plot(num_workers, fb15k_20_50, lw = 4, label = '10 * 50')
ax[0].plot(num_workers, fb15k_10_100, lw = 4, label = '10 * 100')
ax[0].plot(ax[0].get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax[0].set_title('fb15k accuracy')
ax[0].set_ylabel('accuracy (%)')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
ax[0].set_yticks(np.arange(95, 98.5, 0.5))
ax[0].set_xlim(1, 9)
ax[0].set_ylim(95, 98.5)

ax[1].plot(num_workers, wn18_25_40, lw = 4, label = '25 * 40')
ax[1].plot(num_workers, wn18_20_50, lw = 4, label = '10 * 50')
ax[1].plot(num_workers, wn18_10_100, lw = 4, label = '10 * 100')
ax[1].plot(ax[1].get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax[1].set_title('wn18 accuracy')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('accuracy (%)')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
ax[1].set_yticks(np.arange(93, 98, 0.5))
ax[1].set_xlim(1, 9)
ax[1].set_ylim(93, 98)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()

# %%
# Filter.BestHITS
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.616512, 0.605661, 0.588783, 0.595605]) * 100
fb15k_20_50 = np.array([0.615107, 0.603376, 0.601784, 0.595605]) * 100
fb15k_10_100 = np.array([0.594793, 0.588783, 0.586007, 0.575409]) * 100
fb15k_single = 0.6026 * 100

wn18_25_40 = np.array([0.9184, 0.9126, 0.9044, 0.9012]) * 100
wn18_20_50 = np.array([0.906, 0.8954, 0.9084, 0.8938]) * 100
wn18_10_100 = np.array([0.895, 0.8958, 0.8912, 0.886]) * 100
wn18_single = 0.92081 * 100

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].plot(num_workers, fb15k_25_40, lw = 4, label = '25 * 40')
ax[0].plot(num_workers, fb15k_20_50, lw = 4, label = '10 * 50')
ax[0].plot(num_workers, fb15k_10_100, lw = 4, label = '10 * 100')
ax[0].plot(ax[0].get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax[0].set_title('fb15k Filter.BestHITS')
ax[0].set_ylabel('Filter.BestHITS (%)')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
ax[0].set_yticks(np.arange(57, 62.0, 1))
ax[0].set_xlim(1, 9)
ax[0].set_ylim(57, 62.0)

ax[1].plot(num_workers, wn18_25_40, lw = 4, label = '25 * 40')
ax[1].plot(num_workers, wn18_20_50, lw = 4, label = '10 * 50')
ax[1].plot(num_workers, wn18_10_100, lw = 4, label = '10 * 100')
ax[1].plot(ax[1].get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax[1].set_title('wn18 Filter.BestHITS')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('Filter.BestHITS (%)')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
ax[1].set_yticks(np.arange(88, 93, 1))
ax[1].set_xlim(1, 9)
ax[1].set_ylim(88, 93)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()

# %% [markdown]
# ### stacked bar

# %%
# train_time (stacked)
num_workers = np.array([2, 4, 6, 8])

# worker_time = datamodel + sock_load + embedding + sock_save + redis
fb15k_25_40_datamodel = np.array([0.3401276807, 0.325855068, 0.298054844, 0.1325567575])
fb15k_25_40_sock_load = np.array([0.5462547588, 0.5335333917, 0.3557176459, 0.416394618])
fb15k_25_40_embedding = np.array([85.23980161, 44.4426907, 122.8359918, 22.84291017])
fb15k_25_40_sock_save = np.array([0.1282759108, 0.07142202411, 0.07057331115, 0.05421203294])
fb15k_25_40_redis = np.array([0.5674779087, 0.487344307, 0.5421559941, 0.5395510779])

fb15k_20_50_datamodel = np.array([0.3406050008, 0.313007115, 0.1826007673, 0.1325567575])
fb15k_20_50_sock_load = np.array([0.8106703412, 0.5669155443, 0.371867885, 0.416394618])
fb15k_20_50_embedding = np.array([107.7328656, 57.10768155, 39.04383864, 22.84291017])
fb15k_20_50_sock_save = np.array([0.1307839913, 0.07293098123, 0.06974338631, 0.05421203294])
fb15k_20_50_redis = np.array([0.6102354387, 0.5015240617, 0.5504021972, 0.5395510779])

fb15k_10_100_datamodel = np.array([0.3696584893, 0.298054844, 0.1586130786, 0.1325690289])
fb15k_10_100_sock_load = np.array([0.376522072, 0.3557176459, 0.3641109881, 0.3633458575])
fb15k_10_100_embedding = np.array([236.3416694, 122.8359918, 83.84363208, 62.41158417])
fb15k_10_100_sock_save = np.array([0.13108741, 0.07057331115, 0.06616771754, 0.05698246708])
fb15k_10_100_redis = np.array([0.5484508236, 0.5421559941, 0.6037876291, 0.6112810247])

#fb15k_baseline = np.array([])
#fb15k_single = 355.75

wn18_25_40_datamodel = np.array([0.1080404343, 0.04881695769, 0.03405762769, 0.02508027082])
wn18_25_40_sock_load = np.array([0.5586963118, 0.4005548504, 0.361514648, 0.3630288464])
wn18_25_40_embedding = np.array([29.24068487, 16.02682199, 10.58870204, 7.109748179])
wn18_25_40_sock_save = np.array([0.1210655967, 0.07229596031, 0.05425135852, 0.04062943421])
wn18_25_40_redis = np.array([1.004044029, 0.9066149252, 0.965616308, 1.09637809])

wn18_20_50_datamodel = np.array([0.1020654564, 0.05043932748, 0.03377294128, 0.02578567861])
wn18_20_50_sock_load = np.array([0.5143279517, 0.4540479602, 0.3676617114, 0.3723052986])
wn18_20_50_embedding = np.array([39.10120315, 19.54647756, 12.76481233, 9.728899926])
wn18_20_50_sock_save = np.array([0.1164216267, 0.06985209527, 0.05106878868, 0.04007589919])
wn18_20_50_redis = np.array([0.9806994133, 0.9212074395, 1.050629432, 1.129152023])

wn18_10_100_datamodel = np.array([0.1136912884, 0.04708986733, 0.03374366393, 0.02565176771])
wn18_10_100_sock_load = np.array([0.5468547155, 0.3971476892, 0.4674054643, 0.365509457])
wn18_10_100_embedding = np.array([78.12428686, 40.71005184, 27.34394962, 21.48018421])
wn18_10_100_sock_save = np.array([0.1184321803, 0.07073431967, 0.0519099176, 0.04052567605])
wn18_10_100_redis = np.array([1.080649087, 0.9808102034, 1.032042489, 1.317698792])

#wn18_baseline = np.array([187.45, 111.198, 78.3144, 69.2653])
#wn18_single = 104.05

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].bar(num_workers - 0.2, fb15k_25_40_datamodel, width = 0.2, label = '25 * 40 datamodel')
ax[0].bar(num_workers - 0.2, fb15k_25_40_sock_load, width = 0.2, label = '25 * 40 sock_load',
         bottom = fb15k_25_40_datamodel)
ax[0].bar(num_workers - 0.2, fb15k_25_40_embedding, width = 0.2, label = '25 * 40 embedding',
         bottom = fb15k_25_40_datamodel + fb15k_25_40_sock_load)
ax[0].bar(num_workers - 0.2, fb15k_25_40_sock_save, width = 0.2, label = '25 * 40 sock_save',
         bottom = fb15k_25_40_datamodel + fb15k_25_40_sock_load + fb15k_25_40_embedding)
ax[0].bar(num_workers - 0.2, fb15k_25_40_redis, width = 0.2, label = '25 * 40 redis',
         bottom = fb15k_25_40_datamodel + fb15k_25_40_sock_load + fb15k_25_40_embedding + fb15k_25_40_sock_save)

ax[0].bar(num_workers, fb15k_20_50_datamodel, width = 0.2, label = '20 * 50 datamodel')
ax[0].bar(num_workers, fb15k_20_50_sock_load, width = 0.2, label = '20 * 50 sock_load',
         bottom = fb15k_20_50_datamodel)
ax[0].bar(num_workers, fb15k_20_50_embedding, width = 0.2, label = '20 * 50 embedding',
         bottom = fb15k_20_50_datamodel + fb15k_20_50_sock_load)
ax[0].bar(num_workers, fb15k_20_50_sock_save, width = 0.2, label = '20 * 50 sock_save',
         bottom = fb15k_20_50_datamodel + fb15k_20_50_sock_load + fb15k_20_50_embedding)
ax[0].bar(num_workers, fb15k_20_50_redis, width = 0.2, label = '20 * 50 redis',
         bottom = fb15k_20_50_datamodel + fb15k_20_50_sock_load + fb15k_20_50_embedding + fb15k_20_50_sock_save)

ax[0].bar(num_workers + 0.2, fb15k_10_100_datamodel, width = 0.2, label = '10 * 100 datamodel')
ax[0].bar(num_workers + 0.2, fb15k_10_100_sock_load, width = 0.2, label = '10 * 100 sock_load',
         bottom = fb15k_10_100_datamodel)
ax[0].bar(num_workers + 0.2, fb15k_10_100_embedding, width = 0.2, label = '10 * 100 embedding',
         bottom = fb15k_10_100_datamodel + fb15k_10_100_sock_load)
ax[0].bar(num_workers + 0.2, fb15k_10_100_sock_save, width = 0.2, label = '10 * 100 sock_save',
         bottom = fb15k_10_100_datamodel + fb15k_10_100_sock_load + fb15k_10_100_embedding)
ax[0].bar(num_workers + 0.2, fb15k_10_100_redis, width = 0.2, label = '10 * 100 redis',
         bottom = fb15k_10_100_datamodel + fb15k_10_100_sock_load + fb15k_10_100_embedding + fb15k_10_100_sock_save)
ax[0].set_title('fb15k train_time (stacked)')
ax[0].set_ylabel('train_time')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
ax[0].set_yticks(np.arange(0, 250, 25))
ax[0].set_xlim(1, 9)
ax[0].set_ylim(0, 250)

ax[1].bar(num_workers - 0.2, wn18_25_40_datamodel, width = 0.2, label = '25 * 40 datamodel')
ax[1].bar(num_workers - 0.2, wn18_25_40_sock_load, width = 0.2, label = '25 * 40 sock_load',
         bottom = wn18_25_40_datamodel)
ax[1].bar(num_workers - 0.2, wn18_25_40_embedding, width = 0.2, label = '25 * 40 embedding',
         bottom = wn18_25_40_datamodel + wn18_25_40_sock_load)
ax[1].bar(num_workers - 0.2, wn18_25_40_sock_save, width = 0.2, label = '25 * 40 sock_save',
         bottom = wn18_25_40_datamodel + wn18_25_40_sock_load + wn18_25_40_embedding)
ax[1].bar(num_workers - 0.2, wn18_25_40_redis, width = 0.2, label = '25 * 40 redis',
         bottom = wn18_25_40_datamodel + wn18_25_40_sock_load + wn18_25_40_embedding + wn18_25_40_sock_save)

ax[1].bar(num_workers, wn18_20_50_datamodel, width = 0.2, label = '20 * 50 datamodel')
ax[1].bar(num_workers, wn18_20_50_sock_load, width = 0.2, label = '20 * 50 sock_load',
         bottom = wn18_20_50_datamodel)
ax[1].bar(num_workers, wn18_20_50_embedding, width = 0.2, label = '20 * 50 embedding',
         bottom = wn18_20_50_datamodel + wn18_20_50_sock_load)
ax[1].bar(num_workers, wn18_20_50_sock_save, width = 0.2, label = '20 * 50 sock_save',
         bottom = wn18_20_50_datamodel + wn18_20_50_sock_load + wn18_20_50_embedding)
ax[1].bar(num_workers, wn18_20_50_redis, width = 0.2, label = '20 * 50 redis',
         bottom = wn18_20_50_datamodel + wn18_20_50_sock_load + wn18_20_50_embedding + wn18_20_50_sock_save)

ax[1].bar(num_workers + 0.2, wn18_10_100_datamodel, width = 0.2, label = '10 * 100 datamodel')
ax[1].bar(num_workers + 0.2, wn18_10_100_sock_load, width = 0.2, label = '10 * 100 sock_load',
         bottom = wn18_10_100_datamodel)
ax[1].bar(num_workers + 0.2, wn18_10_100_embedding, width = 0.2, label = '10 * 100 embedding',
         bottom = wn18_10_100_datamodel + wn18_10_100_sock_load)
ax[1].bar(num_workers + 0.2, wn18_10_100_sock_save, width = 0.2, label = '10 * 100 sock_save',
         bottom = wn18_10_100_datamodel + wn18_10_100_sock_load + wn18_10_100_embedding)
ax[1].bar(num_workers + 0.2, wn18_10_100_redis, width = 0.2, label = '10 * 100 redis',
         bottom = wn18_10_100_datamodel + wn18_10_100_sock_load + wn18_10_100_embedding + wn18_10_100_sock_save)
ax[1].set_title('wn18 train_time')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('train_time')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
ax[1].set_yticks(np.arange(0, 90, 10))
ax[1].set_xlim(1, 9)
ax[1].set_ylim(0, 90)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()

# %% [markdown]
# ## transE - dbpedia

# %% [markdown]
# ### bar

# %%
# train_time
num_workers = np.array([6, 8])

dbpedia_250_10_50 = np.array([3020.0308, 2685.149056])
#dbpedia_250_baseline = np.array([])
dbpedia_250_single = 28511.6

dbpedia_500_10_100 = np.array([4764.692564, 4193.459808])
dbpedia_500_baseline = np.array([4044.36, 3002])
dbpedia_500_single = 49228.5

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].bar(num_workers, dbpedia_250_10_50, width = 0.2, label = '10 * 50')
#ax[0].bar(num_workers +  0.3, dbpedia_250_baseline, width = 0.2, label = 'baseline')
ax[0].plot(ax[0].get_xlim(), [dbpedia_250_single, dbpedia_250_single], c = 'k', linestyle = '--', label = 'single')
ax[0].set_title('dbpedia_250 train_time')
ax[0].set_ylabel('train_time')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
#ax[0].set_yticks(np.arange(0, 700, 150))
#ax[0].set_xlim(1, 9)
#ax[0].set_ylim(0, 700)

ax[1].bar(num_workers - 0.1, dbpedia_500_10_100, width = 0.2, label = '10 * 100')
ax[1].bar(num_workers +  0.1, dbpedia_500_baseline, width = 0.2, label = 'baseline')
ax[1].plot(ax[1].get_xlim(), [dbpedia_500_single, dbpedia_500_single], c = 'k', linestyle = '--', label = 'single')
ax[1].set_title('dbpedia_500 train_time')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('train_time')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
#ax[1].set_yticks(np.arange(0, 225, 50))
#ax[1].set_xlim(1, 9)
#ax[1].set_ylim(0, 225)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()

# %%
"""

# accuracy
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.975149, 0.968106, 0.962232, 0.958838]) * 100
fb15k_20_50 = np.array([0.975369, 0.966396, 0.960861, 0.958034]) * 100
fb15k_10_100 = np.array([0.972338, 0.962807, 0.956239, 0.952456]) * 100
fb15k_baseline = np.array([96.4077, 96.4001, 96.3798, 96.472])
fb15k_single = 0.98018 * 100

wn18_25_40 = np.array([0.9395, 0.9408, 0.9646, 0.9681]) * 100
wn18_20_50 = np.array([0.933, 0.9406, 0.963, 0.9675]) * 100
wn18_10_100 = np.array([0.9332, 0.9409, 0.963, 0.9607]) * 100
wn18_baseline = np.array([97.01, 96.95, 97, 97.01])
wn18_single = 0.9727 * 100

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 * 40')
ax[0].bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 * 50')
ax[0].bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 * 100')
ax[0].bar(num_workers +  0.3, fb15k_baseline, width = 0.2, label = 'baseline')
ax[0].plot(ax[0].get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax[0].set_title('fb15k accuracy')
ax[0].set_ylabel('accuracy (%)')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
ax[0].set_yticks(np.arange(95, 98.5, 0.5))
ax[0].set_xlim(1, 9)
ax[0].set_ylim(95, 98.5)

ax[1].bar(num_workers - 0.3, wn18_25_40, width = 0.2, label = '25 * 40')
ax[1].bar(num_workers - 0.1, wn18_20_50, width = 0.2, label = '10 * 50')
ax[1].bar(num_workers + 0.1, wn18_10_100, width = 0.2, label = '10 * 100')
ax[1].bar(num_workers +  0.3, wn18_baseline, width = 0.2, label = 'baseline')
ax[1].plot(ax[1].get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax[1].set_title('wn18 accuracy')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('accuracy (%)')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
ax[1].set_yticks(np.arange(93, 98, 0.5))
ax[1].set_xlim(1, 9)
ax[1].set_ylim(93, 98)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()

"""
# Out:
# "\n\n# accuracy\nnum_workers = np.array([2, 4, 6, 8])\n\nfb15k_25_40 = np.array([0.975149, 0.968106, 0.962232, 0.958838]) * 100\nfb15k_20_50 = np.array([0.975369, 0.966396, 0.960861, 0.958034]) * 100\nfb15k_10_100 = np.array([0.972338, 0.962807, 0.956239, 0.952456]) * 100\nfb15k_baseline = np.array([96.4077, 96.4001, 96.3798, 96.472])\nfb15k_single = 0.98018 * 100\n\nwn18_25_40 = np.array([0.9395, 0.9408, 0.9646, 0.9681]) * 100\nwn18_20_50 = np.array([0.933, 0.9406, 0.963, 0.9675]) * 100\nwn18_10_100 = np.array([0.9332, 0.9409, 0.963, 0.9607]) * 100\nwn18_baseline = np.array([97.01, 96.95, 97, 97.01])\nwn18_single = 0.9727 * 100\n\nfig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)\n\nax[0].bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 * 40')\nax[0].bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 * 50')\nax[0].bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 * 100')\nax[0].bar(num_workers +  0.3, fb15k_baseline, width = 0.2, label
# ...

# %%
"""

#Filter.BestHITS
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.612314, 0.607202, 0.601615, 0.587293]) * 100
fb15k_20_50 = np.array([0.611484, 0.602698, 0.598009, 0.588123]) * 100
fb15k_10_100 = np.array([0.601683, 0.586836, 0.587192, 0.574546]) * 100
fb15k_baseline = np.array([45.3124, 45.4817, 45.1601, 45.5807])
fb15k_single = 0.6062 * 100

wn18_25_40 = np.array([0.607, 0.691, 0.8804, 0.8914]) * 100
wn18_20_50 = np.array([0.5732, 0.6736, 0.8772, 0.8802]) * 100
wn18_10_100 = np.array([0.5352, 0.6532, 0.8772, 0.8436]) * 100
wn18_baseline = np.array([84.48, 84.57, 84.97, 83.99])
wn18_single = 0.91341 * 100

fig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)

ax[0].bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 * 40')
ax[0].bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 * 50')
ax[0].bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 * 100')
ax[0].bar(num_workers +  0.3, fb15k_baseline, width = 0.2, label = 'baseline')
ax[0].plot(ax[0].get_xlim(), [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'single')
ax[0].set_title('fb15k Filter.BestHITS')
ax[0].set_ylabel('Filter.BestHITS (%)')
ax[0].legend(loc = 'upper right')
ax[0].set_xticks(num_workers)
ax[0].set_yticks(np.arange(40, 62.0, 3))
ax[0].set_xlim(1, 9)
ax[0].set_ylim(43, 62.0)

ax[1].bar(num_workers - 0.3, wn18_25_40, width = 0.2, label = '25 * 40')
ax[1].bar(num_workers - 0.1, wn18_20_50, width = 0.2, label = '10 * 50')
ax[1].bar(num_workers + 0.1, wn18_10_100, width = 0.2, label = '10 * 100')
ax[1].bar(num_workers +  0.3, wn18_baseline, width = 0.2, label = 'baseline')
ax[1].plot(ax[1].get_xlim(), [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'single')
ax[1].set_title('wn18 Filter.BestHITS')
ax[1].set_xlabel('num worker')
ax[1].set_ylabel('Filter.BestHITS (%)')
ax[1].legend(loc = 'upper right')
ax[1].set_xticks(num_workers)
ax[1].set_yticks(np.arange(50, 94, 5))
ax[1].set_xlim(1, 9)
ax[1].set_ylim(50, 94)

plt.tight_layout()
#plt.savefig('./asdf.pdf', dpi = 300, quality = 100)
plt.show()
"""
# Out:
# "\n\n#Filter.BestHITS\nnum_workers = np.array([2, 4, 6, 8])\n\nfb15k_25_40 = np.array([0.612314, 0.607202, 0.601615, 0.587293]) * 100\nfb15k_20_50 = np.array([0.611484, 0.602698, 0.598009, 0.588123]) * 100\nfb15k_10_100 = np.array([0.601683, 0.586836, 0.587192, 0.574546]) * 100\nfb15k_baseline = np.array([45.3124, 45.4817, 45.1601, 45.5807])\nfb15k_single = 0.6062 * 100\n\nwn18_25_40 = np.array([0.607, 0.691, 0.8804, 0.8914]) * 100\nwn18_20_50 = np.array([0.5732, 0.6736, 0.8772, 0.8802]) * 100\nwn18_10_100 = np.array([0.5352, 0.6532, 0.8772, 0.8436]) * 100\nwn18_baseline = np.array([84.48, 84.57, 84.97, 83.99])\nwn18_single = 0.91341 * 100\n\nfig, ax = plt.subplots(2, 1, figsize = (14, 12), sharex = True)\n\nax[0].bar(num_workers - 0.3, fb15k_25_40, width = 0.2, label = '25 * 40')\nax[0].bar(num_workers - 0.1, fb15k_20_50, width = 0.2, label = '10 * 50')\nax[0].bar(num_workers + 0.1, fb15k_10_100, width = 0.2, label = '10 * 100')\nax[0].bar(num_workers +  0.3, fb15k_baseline, width =
# ...
