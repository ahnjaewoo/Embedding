# %%
import numpy as np
import networkx as nx
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr
import matplotlib.dates as mdates

# %matplotlib inline
plt.rcParams['text.latex.unicode'] = True
#plt.rcParams["font.family"] = 'Times New Roman'
plt.rcParams["font.size"] = 36

# %% [markdown]
# ## fb15k

# %%
# legend
num_workers = np.array([2, 4])

fb15k_maxmin = np.array([133.5354426, 788.316916])
fb15k_randmin = np.array([114.095401, 630.6701311])
fb15k_degmin = np.array([124.3973238, 759.9215757])
fb15k_single = 528.13

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.4, fb15k_maxmin, width = 0.4, label = 'MaxMin', color = 'coral')
ax.bar(num_workers, fb15k_randmin, width = 0.4, label = 'Random selection', color = 'royalblue')
ax.bar(num_workers + 0.4, fb15k_degmin, width = 0.4, label = 'Degree based', color = 'lightseagreen')
ax.set_xlabel('FOR LEGEND')
ax.set_ylabel('DO NOT USE THIS GRAPH')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 4)
ax.set_xticks(num_workers)
ax.set_xticklabels(['transE', 'transG'])
ax.set_yticks(np.arange(0, 800, 150))
ax.set_xlim(1, 5)
ax.set_ylim(0, 850)

#plt.tight_layout()
plt.savefig('./bar_legend_3_anchor.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# train_time fb15k
num_workers = np.array([2, 4])

fb15k_maxmin = np.array([133.5354426, 788.316916])
fb15k_randmin = np.array([114.095401, 630.6701311])
fb15k_degmin = np.array([124.3973238, 759.9215757])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.4, fb15k_maxmin, width = 0.4, label = 'MaxMin', color = 'coral')
ax.bar(num_workers, fb15k_randmin, width = 0.4, label = 'Random selection', color = 'royalblue')
ax.bar(num_workers + 0.4, fb15k_degmin, width = 0.4, label = 'Degree based', color = 'lightseagreen')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Training time (s)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['transE', 'transG'])
ax.set_yticks(np.arange(0, 800, 150))
ax.set_xlim(1, 5)
ax.set_ylim(0, 850)

#plt.tight_layout()
plt.savefig('./anchor_traintime_fb15k.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# accuracy fb15k
num_workers = np.array([2, 4])

fb15k_maxmin = np.array([0.96715, 0.966786]) * 100
fb15k_randmin = np.array([0.964653, 0.96511]) * 100
fb15k_degmin = np.array([0.964737, 0.966549]) * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.4, fb15k_maxmin, width = 0.4, label = 'MaxMin', color = 'coral')
ax.bar(num_workers, fb15k_randmin, width = 0.4, label = 'Random selection', color = 'royalblue')
ax.bar(num_workers + 0.4, fb15k_degmin, width = 0.4, label = 'Degree based', color = 'lightseagreen')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Accuracy (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['transE', 'transG'])
ax.set_yticks(np.arange(0, 101, 10))
ax.set_xlim(1, 5)
ax.set_ylim(70, 100)

#plt.tight_layout()
plt.savefig('./anchor_accuracy_fb15k.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestHITS fb15k
num_workers = np.array([2, 4])

fb15k_maxmin = np.array([0.588377, 0.585736]) * 100
fb15k_randmin = np.array([0.573327, 0.576019]) * 100
fb15k_degmin = np.array([0.585702, 0.580742]) * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.4, fb15k_maxmin, width = 0.4, label = 'MaxMin', color = 'coral')
ax.bar(num_workers, fb15k_randmin, width = 0.4, label = 'Random selection', color = 'royalblue')
ax.bar(num_workers + 0.4, fb15k_degmin, width = 0.4, label = 'Degree based', color = 'lightseagreen')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestHITS (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['transE', 'transG'])
ax.set_yticks(np.arange(0, 100, 10))
ax.set_xlim(1, 5)
ax.set_ylim(0, 65)

#plt.tight_layout()
plt.savefig('./anchor_besthit_fb15k.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestMRR fb15k
num_workers = np.array([2, 4])

fb15k_maxmin = np.array([0.3779, 0.3756])
fb15k_randmin = np.array([0.365252, 0.370458])
fb15k_degmin = np.array([0.372576, 0.368448])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.4, fb15k_maxmin, width = 0.4, label = 'MaxMin', color = 'coral')
ax.bar(num_workers, fb15k_randmin, width = 0.4, label = 'Random selection', color = 'royalblue')
ax.bar(num_workers + 0.4, fb15k_degmin, width = 0.4, label = 'Degree based', color = 'lightseagreen')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestMRR')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['transE', 'transG'])
ax.set_yticks(np.arange(0, 0.41, 0.1))
ax.set_xlim(1, 5)
ax.set_ylim(0, 0.41)

#lt.tight_layout()
plt.savefig('./anchor_bestmrr_fb15k.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## wn18

# %%
# train_time wn18
num_workers = np.array([2, 4])

wn18_maxmin = np.array([83.17734275, 370.6907581])
wn18_randmin = np.array([95.77928302, 488.952681])
wn18_degmin = np.array([96.64268669, 510.4774285])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.4, wn18_maxmin, width = 0.4, label = 'MaxMin', color = 'coral')
ax.bar(num_workers, wn18_randmin, width = 0.4, label = 'Random selection', color = 'royalblue')
ax.bar(num_workers + 0.4, wn18_degmin, width = 0.4, label = 'Degree based', color = 'lightseagreen')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Training time (s)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['transE', 'transG'])
ax.set_yticks(np.arange(0, 800, 100))
ax.set_xlim(1, 5)
ax.set_ylim(0, 550)

#plt.tight_layout()
plt.savefig('./anchor_traintime_wn18.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# accuracy wn18
num_workers = np.array([2, 4])

wn18_maxmin = np.array([0.9648, 0.9707]) * 100
wn18_randmin = np.array([0.9613, 0.9648]) * 100
wn18_degmin = np.array([0.9648, 0.9693]) * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.4, wn18_maxmin, width = 0.4, label = 'MaxMin', color = 'coral')
ax.bar(num_workers, wn18_randmin, width = 0.4, label = 'Random selection', color = 'royalblue')
ax.bar(num_workers + 0.4, wn18_degmin, width = 0.4, label = 'Degree based', color = 'lightseagreen')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Accuracy (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['transE', 'transG'])
ax.set_yticks(np.arange(0, 101, 10))
ax.set_xlim(1, 5)
ax.set_ylim(70, 100)

#plt.tight_layout()
plt.savefig('./anchor_accuracy_wn18.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestHITS wn18
num_workers = np.array([2, 4])

wn18_maxmin = np.array([0.8748, 0.908]) * 100
wn18_randmin = np.array([0.8506, 0.881]) * 100
wn18_degmin = np.array([0.878, 0.9062]) * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.4, wn18_maxmin, width = 0.4, label = 'MaxMin', color = 'coral')
ax.bar(num_workers, wn18_randmin, width = 0.4, label = 'Random selection', color = 'royalblue')
ax.bar(num_workers + 0.4, wn18_degmin, width = 0.4, label = 'Degree based', color = 'lightseagreen')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestHITS (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['transE', 'transG'])
ax.set_yticks(np.arange(0, 100, 15))
ax.set_xlim(1, 5)
ax.set_ylim(0, 95)

#plt.tight_layout()
plt.savefig('./anchor_besthit_wn18.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestMRR wn18
num_workers = np.array([2, 4])

wn18_maxmin = np.array([0.476559, 0.509793])
wn18_randmin = np.array([0.456274, 0.550865])
wn18_degmin = np.array([0.471436, 0.467504])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.4, wn18_maxmin, width = 0.4, label = 'MaxMin', color = 'coral')
ax.bar(num_workers, wn18_randmin, width = 0.4, label = 'Random selection', color = 'royalblue')
ax.bar(num_workers + 0.4, wn18_degmin, width = 0.4, label = 'Degree based', color = 'lightseagreen')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestMRR')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['transE', 'transG'])
ax.set_yticks(np.arange(0, 0.61, 0.1))
ax.set_xlim(1, 5)
ax.set_ylim(0, 0.60)

#lt.tight_layout()
plt.savefig('./anchor_bestmrr_wn18.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## dbpedia

# %%
# train_time dbpedia
num_workers = np.array([2, 4])

dbpedia_maxmin = np.array([])
dbpedia_randmin = np.array([])
dbpedia_degmin = np.array([])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.4, dbpedia_maxmin, width = 0.4, label = 'MaxMin', color = 'coral')
ax.bar(num_workers, dbpedia_randmin, width = 0.4, label = 'Random selection', color = 'royalblue')
ax.bar(num_workers + 0.4, dbpedia_degmin, width = 0.4, label = 'Degree based', color = 'lightseagreen')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Training time (s)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['transE', 'transG'])
ax.set_yticks(np.arange(0, 800, 100))
ax.set_xlim(1, 5)
ax.set_ylim(0, 550)

#plt.tight_layout()
plt.savefig('./anchor_traintime_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# accuracy dbpedia
num_workers = np.array([2, 4])

dbpedia_maxmin = np.array([]) * 100
dbpedia_randmin = np.array([]) * 100
dbpedia_degmin = np.array([]) * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.4, dbpedia_maxmin, width = 0.4, label = 'MaxMin', color = 'coral')
ax.bar(num_workers, dbpedia_randmin, width = 0.4, label = 'Random selection', color = 'royalblue')
ax.bar(num_workers + 0.4, dbpedia_degmin, width = 0.4, label = 'Degree based', color = 'lightseagreen')
ax.set_xlabel('Number of workers')
ax.set_ylabel('Accuracy (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['transE', 'transG'])
ax.set_yticks(np.arange(0, 101, 10))
ax.set_xlim(1, 5)
ax.set_ylim(70, 100)

#plt.tight_layout()
plt.savefig('./anchor_accuracy_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestHITS dbpedia
num_workers = np.array([2, 4])

dbpedia_maxmin = np.array([]) * 100
dbpedia_randmin = np.array([]) * 100
dbpedia_degmin = np.array([]) * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.4, dbpedia_maxmin, width = 0.4, label = 'MaxMin', color = 'coral')
ax.bar(num_workers, dbpedia_randmin, width = 0.4, label = 'Random selection', color = 'royalblue')
ax.bar(num_workers + 0.4, dbpedia_degmin, width = 0.4, label = 'Degree based', color = 'lightseagreen')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestHITS (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['transE', 'transG'])
ax.set_yticks(np.arange(0, 100, 15))
ax.set_xlim(1, 5)
ax.set_ylim(0, 95)

#plt.tight_layout()
plt.savefig('./anchor_besthit_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestMRR dbpedia
num_workers = np.array([2, 4])

dbpedia_maxmin = np.array([])
dbpedia_randmin = np.array([])
dbpedia_degmin = np.array([])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.4, dbpedia_maxmin, width = 0.4, label = 'MaxMin', color = 'coral')
ax.bar(num_workers, dbpedia_randmin, width = 0.4, label = 'Random selection', color = 'royalblue')
ax.bar(num_workers + 0.4, dbpedia_degmin, width = 0.4, label = 'Degree based', color = 'lightseagreen')
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestMRR')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['transE', 'transG'])
ax.set_yticks(np.arange(0, 0.61, 0.1))
ax.set_xlim(1, 5)
ax.set_ylim(0, 0.60)

#lt.tight_layout()
plt.savefig('./anchor_bestmrr_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()
