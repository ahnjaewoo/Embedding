# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr
import matplotlib.dates as mdates

# %matplotlib inline
plt.rcParams['text.latex.unicode'] = True
#plt.rcParams["font.family"] = 'Times New Roman'
plt.rcParams["font.size"] = 36

# %%
# legend
num_workers = np.array([4, 8, 12, 16])

dbpedia_10_50_run = np.array([3033.054561, 1711.859563, 1006.470377, 766.8706456])
dbpedia_10_50_net = np.array([960.7412875, 1199.234252, 1289.828286, 1506.121346])
dbpedia_10_50_idle = np.array([208.2478915, 433.8311336, 626.0032261, 730.3635093])

dbpedia_10_100_run = np.array([6906.556892, 3227.859492, 1915.827266, 1482.775744])
dbpedia_10_100_net = np.array([1165.07427, 1203.200138, 1271.947746, 1525.825388])
dbpedia_10_100_idle = np.array([566.8055814, 641.3242868, 1091.04603, 1263.073797])

dbpedia_20_50_run = np.array([6577.651788, 3255.242416, 1924.759256, 1491.568075])
dbpedia_20_50_net = np.array([2202.86721, 2422.433653, 2562.170321, 3024.028406])
dbpedia_20_50_idle = np.array([841.366371, 806.0584308, 1129.903417, 1380.341025])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 1, dbpedia_10_50_run, width = 0.9, label = 'Embedding', color = '#477ACC', hatch = '/',
      bottom = 0)
ax.bar(num_workers - 1, dbpedia_10_50_net, width = 0.9, label = 'Communication', color = '#F08035', hatch = '/',
      bottom = dbpedia_10_50_run)
ax.bar(num_workers - 1, dbpedia_10_50_idle, width = 0.9, label = 'Idle', color = '#A5A5A5', hatch = '/',
      bottom = dbpedia_10_50_run + dbpedia_10_50_net)

ax.bar(num_workers, dbpedia_10_100_run, width = 0.9, color = '#477ACC', hatch = '/',
      bottom = 0)
ax.bar(num_workers, dbpedia_10_100_net, width = 0.9, color = '#F08035', hatch = '/',
      bottom = dbpedia_10_100_run)
ax.bar(num_workers, dbpedia_10_100_idle, width = 0.9, color = '#A5A5A5', hatch = '/',
      bottom = dbpedia_10_100_run + dbpedia_10_100_net)

ax.bar(num_workers + 1, dbpedia_20_50_run, width = 0.9, color = '#477ACC', hatch = '/',
      bottom = 0)
ax.bar(num_workers + 1, dbpedia_20_50_net, width = 0.9, color = '#F08035', hatch = '/',
      bottom = dbpedia_20_50_run)
ax.bar(num_workers + 1, dbpedia_20_50_idle, width = 0.9, color = '#A5A5A5', hatch = '/',
      bottom = dbpedia_20_50_run + dbpedia_20_50_net)

ax.set_xlabel('FOR LEGEND')
ax.set_ylabel('DO NOT USE THIS GRAPH')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 4)

ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 14000, 2000))
ax.set_xlim(1, 19)
ax.set_ylim(0, 11000)

ax.set_yticklabels(['{:,}'.format(v) + 's' for v in range(0, 14000, 2000)])

#plt.tight_layout()
plt.savefig('./bar_legend_3_profile.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# train_time dbpedia transe
num_workers = np.array([4, 8, 12, 16])

dbpedia_10_50_run = np.array([3033.054561, 1711.859563, 1006.470377, 766.8706456])
dbpedia_10_50_net = np.array([960.7412875, 1199.234252, 1289.828286, 1506.121346])
dbpedia_10_50_idle = np.array([208.2478915, 433.8311336, 626.0032261, 730.3635093])

dbpedia_10_100_run = np.array([6906.556892, 3227.859492, 1915.827266, 1482.775744])
dbpedia_10_100_net = np.array([1165.07427, 1203.200138, 1271.947746, 1525.825388])
dbpedia_10_100_idle = np.array([566.8055814, 641.3242868, 1091.04603, 1263.073797])

dbpedia_20_50_run = np.array([6577.651788, 3255.242416, 1924.759256, 1491.568075])
dbpedia_20_50_net = np.array([2202.86721, 2422.433653, 2562.170321, 3024.028406])
dbpedia_20_50_idle = np.array([841.366371, 806.0584308, 1129.903417, 1380.341025])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 1, dbpedia_10_50_run, width = 0.9, color = '#477ACC', hatch = '/',
      bottom = 0)
ax.bar(num_workers - 1, dbpedia_10_50_net, width = 0.9, color = '#F08035', hatch = '/',
      bottom = dbpedia_10_50_run)
ax.bar(num_workers - 1, dbpedia_10_50_idle, width = 0.9, color = '#A5A5A5', hatch = '/',
      bottom = dbpedia_10_50_run + dbpedia_10_50_net)

ax.bar(num_workers, dbpedia_10_100_run, width = 0.9, color = '#477ACC', hatch = '/',
      bottom = 0)
ax.bar(num_workers, dbpedia_10_100_net, width = 0.9, color = '#F08035', hatch = '/',
      bottom = dbpedia_10_100_run)
ax.bar(num_workers, dbpedia_10_100_idle, width = 0.9, color = '#A5A5A5', hatch = '/',
      bottom = dbpedia_10_100_run + dbpedia_10_100_net)

ax.bar(num_workers + 1, dbpedia_20_50_run, width = 0.9, color = '#477ACC', hatch = '/',
      bottom = 0)
ax.bar(num_workers + 1, dbpedia_20_50_net, width = 0.9, color = '#F08035', hatch = '/',
      bottom = dbpedia_20_50_run)
ax.bar(num_workers + 1, dbpedia_20_50_idle, width = 0.9, color = '#A5A5A5', hatch = '/',
      bottom = dbpedia_20_50_run + dbpedia_20_50_net)

ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 14000, 2000))
ax.set_xlim(1, 19)
ax.set_ylim(0, 11000)

ax.set_yticklabels(['{:,}'.format(v) + 's' for v in range(0, 14000, 2000)])

#plt.tight_layout()
plt.savefig('./bar_profile_transe_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# train_time dbpedia transg
num_workers = np.array([4, 8, 12, 16])

dbpedia_10_50_run = np.array([18020.72965, 8992.10054, 4716.745523, 3553.141162])
dbpedia_10_50_net = np.array([1010.07625, 1216.988019, 1319.001827, 1553.454274])
dbpedia_10_50_idle = np.array([1725.93627, 1575.681321, 2342.112879, 2645.56015])

dbpedia_10_100_run = np.array([31374.59481, 16502.59941, 8092.413381, 6130.205324])
dbpedia_10_100_net = np.array([1001.891043, 1307.438282, 1320.456616, 1592.201788])
dbpedia_10_100_idle = np.array([2680.844827, 2834.280018, 4138.938143, 4809.201088])

dbpedia_20_50_run = np.array([30959.05058, 16405.12378, 8166.718224, 6077.647038])
dbpedia_20_50_net = np.array([2000.532493, 2592.044203, 2555.849239, 3126.508942])
dbpedia_20_50_idle = np.array([1745.118437, 2943.499635, 3968.408637, 4723.17036])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 1, dbpedia_10_50_run, width = 0.9, color = '#477ACC', hatch = '/',
      bottom = 0)
ax.bar(num_workers - 1, dbpedia_10_50_net, width = 0.9, color = '#F08035', hatch = '/',
      bottom = dbpedia_10_50_run)
ax.bar(num_workers - 1, dbpedia_10_50_idle, width = 0.9, color = '#A5A5A5', hatch = '/',
      bottom = dbpedia_10_50_run + dbpedia_10_50_net)

ax.bar(num_workers, dbpedia_10_100_run, width = 0.9, color = '#477ACC', hatch = '/',
      bottom = 0)
ax.bar(num_workers, dbpedia_10_100_net, width = 0.9, color = '#F08035', hatch = '/',
      bottom = dbpedia_10_100_run)
ax.bar(num_workers, dbpedia_10_100_idle, width = 0.9, color = '#A5A5A5', hatch = '/',
      bottom = dbpedia_10_100_run + dbpedia_10_100_net)

ax.bar(num_workers + 1, dbpedia_20_50_run, width = 0.9, color = '#477ACC', hatch = '/',
      bottom = 0)
ax.bar(num_workers + 1, dbpedia_20_50_net, width = 0.9, color = '#F08035', hatch = '/',
      bottom = dbpedia_20_50_run)
ax.bar(num_workers + 1, dbpedia_20_50_idle, width = 0.9, color = '#A5A5A5', hatch = '/',
      bottom = dbpedia_20_50_run + dbpedia_20_50_net)

ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 40001, 5000))
ax.set_xlim(1, 19)
ax.set_ylim(0, 43000)

ax.set_yticklabels(['{:,}'.format(v) + 's' for v in range(0, 40001, 5000)])
ax.yaxis.set_label_position('right')
ax.yaxis.tick_right()

#plt.tight_layout()
plt.savefig('./bar_profile_transg_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()
