# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr
import matplotlib.dates as mdates

# %matplotlib inline
plt.rcParams['text.latex.unicode'] = True
#plt.rcParams["font.family"] = 'Times New Roman'
plt.rcParams["font.size"] = 36

# %% [markdown]
# ## transE

# %%
# train_time wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([185.5449607, 123.1282524, 113.9996282, 115.045892])
wn18_20_50 = np.array([170.0560047, 113.7906844, 121.7531179, 102.1393621])
wn18_10_100 = np.array([139.3812391, 89.33367668, 77.6461272, 75.23492091])
wn18_5_200 = np.array([131.9433594, 74.51147913, 68.29448221, 59.39934323])
wn18_5_100 = np.array([78.71546376, 47.0370721, 40.30920011, 40.61043695])
wn18_baseline = np.array([187.45, 111.198, 78.3144, 69.2653])
wn18_single = 151.662

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.625, wn18_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.375, wn18_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.125, wn18_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.125, wn18_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.375, wn18_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.bar(num_workers +  0.625, wn18_baseline, width = 0.25, label = 'paragraphE', color = '#A5A5A5')
ax.plot([0, 10], [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 220, 50))
ax.set_xlim(1, 9)
ax.set_ylim(0, 210)

ax.set_yticklabels(['{:,}'.format(v) + 's' for v in range(0, 220, 50)])

#plt.tight_layout()
plt.savefig('./bar_traintime_transe_wn18.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# accuracy wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([0.9319, 0.9421, 0.9673, 0.97]) * 100
wn18_20_50 = np.array([0.9322, 0.9436, 0.9672, 0.9692]) * 100
wn18_10_100 = np.array([0.9349, 0.9351, 0.9638, 0.9655]) * 100
wn18_5_200 = np.array([0.936, 0.9378, 0.9586, 0.959]) * 100
wn18_5_100 = np.array([0.9211, 0.9266, 0.9516, 0.9507]) * 100
wn18_baseline = np.array([0.9701, 0.9695, 0.97, 0.9701]) * 100
wn18_single = 0.975105 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.625, wn18_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.375, wn18_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.125, wn18_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.125, wn18_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.375, wn18_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.bar(num_workers +  0.625, wn18_baseline, width = 0.25, label = 'paragraphE', color = '#A5A5A5')
ax.plot([0, 10], [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 101, 5))
ax.set_xlim(1, 9)
ax.set_ylim(85, 101)

ax.set_yticklabels([str(v) + '%' for v in range(0, 101, 5)])
ax.yaxis.set_label_position('right')
ax.yaxis.tick_right()

#plt.tight_layout()
plt.savefig('./bar_accuracy_transe_wn18.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# BestHITS wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([0.5832, 0.6912, 0.8938, 0.9024]) * 100
wn18_20_50 = np.array([0.567, 0.6766, 0.8918, 0.9008]) * 100
wn18_10_100 = np.array([0.573, 0.6532, 0.8746, 0.8728]) * 100
wn18_5_200 = np.array([0.531, 0.6224, 0.8064, 0.8218]) * 100
wn18_5_100 = np.array([0.4618, 0.6018, 0.7844, 0.7688]) * 100
wn18_baseline = np.array([0.8448, 0.8457, 0.8497, 0.8399]) * 100
wn18_single = 0.912817 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.625, wn18_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.375, wn18_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.125, wn18_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.125, wn18_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.375, wn18_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.bar(num_workers +  0.625, wn18_baseline, width = 0.25, label = 'paragraphE', color = '#A5A5A5')
ax.plot([0, 10], [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 101, 20))
ax.set_xlim(1, 9)
ax.set_ylim(0, 105)

ax.set_yticklabels([str(v) + '%' for v in range(0, 101, 20)])

#plt.tight_layout()
plt.savefig('./bar_besthit_transe_wn18.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# BestMRR wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([0.38962, 0.54684, 0.490428, 0.508867])
wn18_20_50 = np.array([0.377785, 0.534874, 0.491493, 0.507596])
wn18_10_100 = np.array([0.366236, 0.51178, 0.46679, 0.469234])
wn18_5_200 = np.array([0.325253, 0.436408, 0.403263, 0.421377])
wn18_5_100 = np.array([0.288, 0.425399, 0.393691, 0.379015])
wn18_baseline = np.array([0.350128, 0.347224, 0.348321, 0.341686])
wn18_single = 0.458869

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.625, wn18_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.375, wn18_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.125, wn18_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.125, wn18_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.375, wn18_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.bar(num_workers +  0.625, wn18_baseline, width = 0.25, label = 'paragraphE', color = '#A5A5A5')
ax.plot([0, 10], [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 1, 0.15))
ax.set_xlim(1, 9)
ax.set_ylim(0, 0.64)

ax.yaxis.set_label_position('right')
ax.yaxis.tick_right()

#plt.tight_layout()
plt.savefig('./bar_bestmrr_transe_wn18.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## transG

# %%
# train_time wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([850.3244594, 630.5530105, 406.1931913, 505.207548])
wn18_20_50 = np.array([896.6568698, 506.3359468, 423.9557039, 488.132839])
wn18_10_100 = np.array([959.1047899, 489.9436855, 567.7015734, 500.5373147])
wn18_5_200 = np.array([1028.648315, 559.3461165, 573.6385209, 514.044138])
wn18_5_100 = np.array([556.0388418, 327.1584813, 292.3441988, 287.2294245])
wn18_single = 953.435

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.50, wn18_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.25, wn18_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, wn18_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.25, wn18_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.50, wn18_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.plot([0, 10], [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 2000, 200))
ax.set_xlim(1, 9)
ax.set_ylim(0, 1100)

ax.set_yticklabels(['{:,}'.format(v) + 's' for v in range(0, 2000, 200)])

#plt.tight_layout()
plt.savefig('./bar_traintime_transg_wn18.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# accuracy wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([0.9747, 0.9717, 0.9706, 0.9722]) * 100
wn18_20_50 = np.array([0.9751, 0.9729, 0.9728, 0.9696]) * 100
wn18_10_100 = np.array([0.9724, 0.9704, 0.9664, 0.9711]) * 100
wn18_5_200 = np.array([0.9704, 0.9628, 0.965, 0.9584]) * 100
wn18_5_100 = np.array([0.9687, 0.9625, 0.9608, 0.9608]) * 100
wn18_single = 0.978004 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.50, wn18_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.25, wn18_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, wn18_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.25, wn18_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.50, wn18_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.plot([0, 10], [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 101, 5))
ax.set_xlim(1, 9)
ax.set_ylim(85, 101)

ax.set_yticklabels([str(v) + '%' for v in range(0, 101, 5)])
ax.yaxis.set_label_position('right')
ax.yaxis.tick_right()

#plt.tight_layout()
plt.savefig('./bar_accuracy_transg_wn18.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# BestHITS wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([0.928, 0.9268, 0.9188, 0.9184]) * 100
wn18_20_50 = np.array([0.9272, 0.9182, 0.9166, 0.9168]) * 100
wn18_10_100 = np.array([0.9224, 0.9108, 0.9038, 0.9078]) * 100
wn18_5_200 = np.array([0.8928, 0.866, 0.8816, 0.8668]) * 100
wn18_5_100 = np.array([0.8918, 0.8688, 0.867, 0.8586]) * 100
wn18_single = 0.927015 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.50, wn18_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.25, wn18_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, wn18_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.25, wn18_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.50, wn18_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.plot([0, 10], [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 101, 20))
ax.set_xlim(1, 9)
ax.set_ylim(0, 105)

ax.set_yticklabels([str(v) + '%' for v in range(0, 101, 20)])

#plt.tight_layout()
plt.savefig('./bar_besthit_transg_wn18.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# BestMRR wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([0.471654, 0.467594, 0.462934, 0.467436])
wn18_20_50 = np.array([0.470729, 0.461535, 0.471896, 0.486972])
wn18_10_100 = np.array([0.4768, 0.441863, 0.535026, 0.485107])
wn18_5_200 = np.array([0.50345, 0.507097, 0.546007, 0.502622])
wn18_5_100 = np.array([0.427821, 0.431282, 0.41323, 0.407177])
wn18_single = 0.54735

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.50, wn18_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.25, wn18_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, wn18_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.25, wn18_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.50, wn18_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.plot([0, 10], [wn18_single, wn18_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 1, 0.15))
ax.set_xlim(1, 9)
ax.set_ylim(0, 0.65)

ax.yaxis.set_label_position('right')
ax.yaxis.tick_right()

#plt.tight_layout()
plt.savefig('./bar_bestmrr_transg_wn18.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Speed Up

# %%
# train_time wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([185.5449607, 123.1282524, 113.9996282, 115.045892])
wn18_20_50 = np.array([170.0560047, 113.7906844, 121.7531179, 102.1393621])
wn18_10_100 = np.array([139.3812391, 89.33367668, 77.6461272, 75.23492091])
wn18_5_200 = np.array([131.9433594, 74.51147913, 68.29448221, 59.39934323])
wn18_5_100 = np.array([78.71546376, 47.0370721, 40.30920011, 40.61043695])
wn18_baseline = np.array([187.45, 111.198, 78.3144, 69.2653])
wn18_single = 151.662

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.plot(num_workers, wn18_single / wn18_25_40, marker = 'D', linestyle = '-', label = '25 / 40',
        lw = 4, markersize = 12, color = '#3B65A9')
ax.plot(num_workers, wn18_single / wn18_20_50, marker = 'o', linestyle = '-', label = '20 / 50',
        lw = 4, markersize = 12, color = '#D4722F')
ax.plot(num_workers, wn18_single / wn18_10_100, marker = 'v', linestyle = '-', label = '10 / 100',
        lw = 4, markersize = 12, color = '#70AD47')
ax.plot(num_workers, wn18_single / wn18_5_200, marker = '^', linestyle = '-', label = '5 / 200',
        lw = 4, markersize = 12, color = '#E5AE16')
ax.plot(num_workers, wn18_single / wn18_5_100, marker = '*', linestyle = '-', label = '5 / 100',
        lw = 4, markersize = 12, color = '#8957A1')
ax.plot(num_workers, wn18_single / wn18_baseline, marker = 's', linestyle = '-', label = 'paragraphE',
        lw = 4, markersize = 12, color = '#A5A5A5')
ax.plot([1, 8], [1, 8], c = 'k', linestyle = '--', label = 'Ideal', lw = 4, zorder = -1)
ax.set_xlim(0, 9)
ax.set_ylim(0, 9)
ax.set_xticks(num_workers)
ax.set_yticks(num_workers)
ax.set_xlabel('Number of workers')
ax.set_ylabel('Speed up')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 4)

#plt.tight_layout()
plt.savefig('./line_speedup_transe_wn18.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# train_time wn18
num_workers = np.array([2, 4, 6, 8])

wn18_25_40 = np.array([850.3244594, 630.5530105, 406.1931913, 505.207548])
wn18_20_50 = np.array([896.6568698, 506.3359468, 423.9557039, 488.132839])
wn18_10_100 = np.array([959.1047899, 489.9436855, 567.7015734, 500.5373147])
wn18_5_200 = np.array([1028.648315, 559.3461165, 573.6385209, 514.044138])
wn18_5_100 = np.array([556.0388418, 327.1584813, 292.3441988, 287.2294245])
wn18_single = 953.435

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.plot(num_workers, wn18_single / wn18_25_40, marker = 'D', linestyle = '-', label = '25 / 40',
        lw = 4, markersize = 12, color = '#3B65A9')
ax.plot(num_workers, wn18_single / wn18_20_50, marker = 'o', linestyle = '-', label = '20 / 50',
        lw = 4, markersize = 12, color = '#D4722F')
ax.plot(num_workers, wn18_single / wn18_10_100, marker = 'v', linestyle = '-', label = '10 / 100',
        lw = 4, markersize = 12, color = '#70AD47')
ax.plot(num_workers, wn18_single / wn18_5_200, marker = '^', linestyle = '-', label = '5 / 200',
        lw = 4, markersize = 12, color = '#E5AE16')
ax.plot(num_workers, wn18_single / wn18_5_100, marker = '*', linestyle = '-', label = '5 / 100',
        lw = 4, markersize = 12, color = '#8957A1')
ax.plot([1, 8], [1, 8], c = 'k', linestyle = '--', label = 'Ideal', lw = 4, zorder = -1)
ax.set_xlim(0, 9)
ax.set_ylim(0, 9)
ax.set_xticks(num_workers)
ax.set_yticks(num_workers)
ax.set_xlabel('Number of workers')
ax.set_ylabel('Speed up')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 3)

#plt.tight_layout()
plt.savefig('./line_speedup_transg_wn18.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()
