# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr
import matplotlib.dates as mdates

# %matplotlib inline
plt.rcParams['text.latex.unicode'] = True
#plt.rcParams["font.family"] = 'Times New Roman'
plt.rcParams["font.size"] = 36

# %% [markdown]
# ## transE

# %%
# legend
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([9621.885369, 6483.7345, 5616.832994, 5895.937505])
dbpedia_10_100 = np.array([8638.436743, 5072.383917, 4278.821042, 4271.674929])
dbpedia_10_50 = np.array([4202.04374, 3344.924949, 2922.301889, 3003.355501])
dbpedia_baseline = np.array([5206.37, 3002, 1940.23, 1837.61])
dbpedia_single = 12490.4

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 1.05, dbpedia_20_50, width = 0.7, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.35, dbpedia_10_100, width = 0.7, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.35, dbpedia_10_50, width = 0.7, label = '10 / 50', color = '#548BBD')
ax.bar(num_workers + 1.05, dbpedia_baseline, width = 0.7, label = 'paragraphE', color = '#A5A5A5')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('FOR LEGEND')
ax.set_ylabel('DO NOT USE THIS GRAPH')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 3)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 15000, 2000))
ax.set_xlim(2, 18)
ax.set_ylim(0, 13500)

#plt.tight_layout()
plt.savefig('./bar_legend_5_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# train_time dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([9621.885369, 6483.7345, 5616.832994, 5895.937505])
dbpedia_10_100 = np.array([8638.436743, 5072.383917, 4278.821042, 4271.674929])
dbpedia_10_50 = np.array([4202.04374, 3344.924949, 2922.301889, 3003.355501])
dbpedia_baseline = np.array([5206.37, 3002, 1940.23, 1837.61])
dbpedia_single = 12490.4

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 1.05, dbpedia_20_50, width = 0.7, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.35, dbpedia_10_100, width = 0.7, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.35, dbpedia_10_50, width = 0.7, label = '10 / 50', color = '#548BBD')
ax.bar(num_workers + 1.05, dbpedia_baseline, width = 0.7, label = 'paragraphE', color = '#A5A5A5')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 15000, 2000))
ax.set_xlim(2, 18)
ax.set_ylim(0, 13500)

ax.set_yticklabels(['{:,}'.format(v) + 's' for v in range(0, 15000, 2000)])

#plt.tight_layout()
plt.savefig('./bar_traintime_transe_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# accuracy dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([0.973417, 0.969542, 0.969042, 0.965833]) * 100
dbpedia_10_100 = np.array([0.972875, 0.968292, 0.967583, 0.964417]) * 100
dbpedia_10_50 = np.array([0.966625, 0.962292, 0.96075, 0.959542]) * 100
dbpedia_baseline = np.array([0.958792, 0.957708, 0.962667, 0.961833]) * 100
dbpedia_single = 0.978186 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 1.05, dbpedia_20_50, width = 0.7, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.35, dbpedia_10_100, width = 0.7, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.35, dbpedia_10_50, width = 0.7, label = '10 / 50', color = '#548BBD')
ax.bar(num_workers + 1.05, dbpedia_baseline, width = 0.7, label = 'paragraphE', color = '#A5A5A5')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 101, 5))
ax.set_xlim(2, 18)
ax.set_ylim(85, 101)

ax.set_yticklabels([str(v) + '%' for v in range(0, 101, 5)])
ax.yaxis.set_label_position('right')
ax.yaxis.tick_right()

#plt.tight_layout()
plt.savefig('./bar_accuracy_transe_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# BestHITS dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([0.3975, 0.416167, 0.417167, 0.427833]) * 100
dbpedia_10_100 = np.array([0.382417, 0.406917, 0.4005, 0.418417]) * 100
dbpedia_10_50 = np.array([0.338333, 0.37, 0.366417, 0.38225]) * 100
dbpedia_baseline = np.array([0.157667, 0.188083, 0.154708, 0.190667]) * 100
dbpedia_single = 0.391634 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 1.05, dbpedia_20_50, width = 0.7, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.35, dbpedia_10_100, width = 0.7, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.35, dbpedia_10_50, width = 0.7, label = '10 / 50', color = '#548BBD')
ax.bar(num_workers + 1.05, dbpedia_baseline, width = 0.7, label = 'paragraphE', color = '#A5A5A5')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 101, 10))
ax.set_xlim(2, 18)
ax.set_ylim(0, 48)

ax.set_yticklabels([str(v) + '%' for v in range(0, 101, 10)])

#plt.tight_layout()
plt.savefig('./bar_besthit_transe_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# BestMRR dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([0.188051, 0.197917, 0.200453, 0.208015])
dbpedia_10_100 = np.array([0.17958, 0.192347, 0.190591, 0.202242])
dbpedia_10_50 = np.array([0.16041, 0.173717, 0.171052, 0.180263])
dbpedia_baseline = np.array([0.0726935, 0.0777017, 0.0721276, 0.0796954])
dbpedia_single = 0.193396

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 1.05, dbpedia_20_50, width = 0.7, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.35, dbpedia_10_100, width = 0.7, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.35, dbpedia_10_50, width = 0.7, label = '10 / 50', color = '#548BBD')
ax.bar(num_workers + 1.05, dbpedia_baseline, width = 0.7, label = 'paragraphE', color = '#A5A5A5')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 0.41, 0.05))
ax.set_xlim(2, 18)
ax.set_ylim(0, 0.23)

ax.yaxis.set_label_position('right')
ax.yaxis.tick_right()

#lt.tight_layout()
plt.savefig('./bar_bestmrr_transe_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## transG

# %%
# legend
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([34704.70151, 21940.66762, 14690.9761, 13927.32634])
dbpedia_10_100 = np.array([35057.33068, 20644.31771, 13551.80814, 12531.6082])
dbpedia_10_50 = np.array([20756.74217, 11784.76988, 8377.860229, 7752.155586])
dbpedia_single = 49228.5

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.8, dbpedia_20_50, width = 0.8, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, dbpedia_10_100, width = 0.8, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.8, dbpedia_10_50, width = 0.8, label = '10 / 50', color = '#548BBD')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('FOR LEGEND')
ax.set_ylabel('DO NOT USE THIS GRAPH')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 4)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 60000, 10000))
ax.set_xlim(2, 18)
ax.set_ylim(0, 55000)

#plt.tight_layout()
plt.savefig('./bar_legend_4_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# train_time dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([34704.70151, 21940.66762, 14690.9761, 13927.32634])
dbpedia_10_100 = np.array([35057.33068, 20644.31771, 13551.80814, 12531.6082])
dbpedia_10_50 = np.array([20756.74217, 11784.76988, 8377.860229, 7752.155586])
dbpedia_single = 49228.5

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.8, dbpedia_20_50, width = 0.8, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, dbpedia_10_100, width = 0.8, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.8, dbpedia_10_50, width = 0.8, label = '10 / 50', color = '#548BBD')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 60000, 10000))
ax.set_xlim(2, 18)
ax.set_ylim(0, 55000)

ax.set_yticklabels(['{:,}'.format(v) + 's' for v in range(0, 60000, 10000)])

#plt.tight_layout()
plt.savefig('./bar_traintime_transg_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# accuracy dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([0.975167, 0.972542, 0.970958, 0.967917]) * 100
dbpedia_10_100 = np.array([0.974333, 0.970875, 0.96725, 0.964792]) * 100
dbpedia_10_50 = np.array([0.969542, 0.966792, 0.962083, 0.96275]) * 100
dbpedia_single = 0.98446 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.8, dbpedia_20_50, width = 0.8, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, dbpedia_10_100, width = 0.8, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.8, dbpedia_10_50, width = 0.8, label = '10 / 50', color = '#548BBD')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 101, 5))
ax.set_xlim(2, 18)
ax.set_ylim(85, 101)

ax.set_yticklabels([str(v) + '%' for v in range(0, 101, 5)])
ax.yaxis.set_label_position('right')
ax.yaxis.tick_right()

#plt.tight_layout()
plt.savefig('./bar_accuracy_transg_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# BestHITS dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([0.401, 0.42375, 0.4245, 0.448583]) * 100
dbpedia_10_100 = np.array([0.362917, 0.386667, 0.395333, 0.414917]) * 100
dbpedia_10_50 = np.array([0.34275, 0.375583, 0.37375, 0.383]) * 100
dbpedia_single = 0.395884 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.8, dbpedia_20_50, width = 0.8, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, dbpedia_10_100, width = 0.8, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.8, dbpedia_10_50, width = 0.8, label = '10 / 50', color = '#548BBD')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 101, 10))
ax.set_xlim(2, 18)
ax.set_ylim(0, 52)

ax.set_yticklabels([str(v) + '%' for v in range(0, 101, 10)])

#plt.tight_layout()
plt.savefig('./bar_besthit_transg_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# BestMRR dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([0.200442, 0.208784, 0.210299, 0.22166])
dbpedia_10_100 = np.array([0.181598, 0.196635, 0.202384, 0.210086])
dbpedia_10_50 = np.array([0.170648, 0.188049, 0.185348, 0.190602])
dbpedia_single = 0.199667

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.8, dbpedia_20_50, width = 0.8, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, dbpedia_10_100, width = 0.8, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.8, dbpedia_10_50, width = 0.8, label = '10 / 50', color = '#548BBD')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 0.41, 0.05))
ax.set_xlim(2, 18)
ax.set_ylim(0, 0.265)

ax.yaxis.set_label_position('right')
ax.yaxis.tick_right()

#plt.tight_layout()
plt.savefig('./bar_bestmrr_transg_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Speed Up

# %%
# train_time dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([9621.885369, 6483.7345, 5616.832994, 5895.937505])
dbpedia_10_100 = np.array([8638.436743, 5072.383917, 4278.821042, 4271.674929])
dbpedia_10_50 = np.array([4202.04374, 3344.924949, 2922.301889, 3003.355501])
dbpedia_baseline = np.array([5206.37, 3002, 1940.23, 1837.61])
dbpedia_single = 12490.4

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.plot(num_workers, dbpedia_single / dbpedia_20_50, marker = 'D', linestyle = '-', label = '20 / 50',
        lw = 4, markersize = 12, color = '#D4722F')
ax.plot(num_workers, dbpedia_single / dbpedia_10_100, marker = 'D', linestyle = '-', label = '10 / 100',
        lw = 4, markersize = 12, color = '#70AD47')
ax.plot(num_workers, dbpedia_single / dbpedia_10_50, marker = 'D', linestyle = '-', label = '10 / 50',
        lw = 4, markersize = 12, color = '#548BBD')
ax.plot(num_workers, dbpedia_single / dbpedia_baseline, marker = 'D', linestyle = '-', label = 'paragraphE',
        lw = 4, markersize = 12, color = '#A5A5A5')
ax.plot([1, 16], [1, 16], c = 'k', linestyle = '--', label = 'Ideal', lw = 4, zorder = -1)
ax.set_xlim(0, 17)
ax.set_ylim(0, 17)
ax.set_xticks(num_workers)
ax.set_yticks(num_workers)
ax.set_xlabel('Number of workers')
ax.set_ylabel('Speed up')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 3)

#plt.tight_layout()
plt.savefig('./line_speedup_transe_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# train_time dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([34704.70151, 21940.66762, 14690.9761, 13927.32634])
dbpedia_10_100 = np.array([35057.33068, 20644.31771, 13551.80814, 12531.6082])
dbpedia_10_50 = np.array([20756.74217, 11784.76988, 8377.860229, 7752.155586])
dbpedia_single = 49228.5

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.plot(num_workers, dbpedia_single / dbpedia_20_50, marker = 'D', linestyle = '-', label = '20 / 50',
        lw = 4, markersize = 12, color = '#D4722F')
ax.plot(num_workers, dbpedia_single / dbpedia_10_100, marker = 'D', linestyle = '-', label = '10 / 100',
        lw = 4, markersize = 12, color = '#70AD47')
ax.plot(num_workers, dbpedia_single / dbpedia_10_50, marker = 'D', linestyle = '-', label = '10 / 50',
        lw = 4, markersize = 12, color = '#548BBD')
ax.plot([1, 16], [1, 16], c = 'k', linestyle = '--', label = 'Ideal', lw = 4, zorder = -1)
ax.set_xlim(0, 17)
ax.set_ylim(0, 17)
ax.set_xticks(num_workers)
ax.set_yticks(num_workers)
ax.set_xlabel('Number of workers')
ax.set_ylabel('Speed up')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 3)

#plt.tight_layout()
plt.savefig('./line_speedup_transg_dbpedia.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()
