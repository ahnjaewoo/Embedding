# %%
import numpy as np
import networkx as nx
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr
import matplotlib.dates as mdates

# %matplotlib inline
plt.rcParams['text.latex.unicode'] = True
#plt.rcParams["font.family"] = 'Times New Roman'
plt.rcParams["font.size"] = 36

# %% [markdown]
# ## transE

# %%
# legend
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([12526.0495, 11706.07844, 11688.71865, 0])
dbpedia_10_100 = np.array([8020.278674, 6939.225305, 6701.179072, 0])
dbpedia_baseline = np.array([6440.28, 3356.9, 2390.27, 1936.63])
dbpedia_single = 12490.4

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.8, dbpedia_20_50, width = 0.8, label = '20 / 50', color = 'tab:orange')
ax.bar(num_workers, dbpedia_10_100, width = 0.8, label = '10 / 100', color = 'tab:green')
ax.bar(num_workers + 0.8, dbpedia_baseline, width = 0.8, label = 'paragraphE', color = 'tab:brown')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('FOR LEGEND')
ax.set_ylabel('DO NOT USE THIS GRAPH')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 4)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 15000, 2000))
ax.set_xlim(2, 18)
ax.set_ylim(0, 13500)

#plt.tight_layout()
plt.savefig('./bar_legend_4_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# train_time dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([12526.0495, 11706.07844, 11688.71865, 0])
dbpedia_10_100 = np.array([8020.278674, 6939.225305, 6701.179072, 0])
dbpedia_baseline = np.array([6440.28, 3356.9, 2390.27, 1936.63])
dbpedia_single = 12490.4

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.8, dbpedia_20_50, width = 0.8, label = '20 / 50', color = 'tab:orange')
ax.bar(num_workers, dbpedia_10_100, width = 0.8, label = '10 / 100', color = 'tab:green')
ax.bar(num_workers + 0.8, dbpedia_baseline, width = 0.8, label = 'paragraphE', color = 'tab:brown')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('Number of workers')
ax.set_ylabel('Training time (s)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 15000, 2000))
ax.set_xlim(2, 18)
ax.set_ylim(0, 13500)

#plt.tight_layout()
plt.savefig('./bar_traintime_transe_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# accuracy dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([0.971375, 0.969208, 0.968708, 0]) * 100
dbpedia_10_100 = np.array([0.97, 0.966625, 0.965625, 0]) * 100
dbpedia_baseline = np.array([0.900708, 0.903792, 0.902042, 0.902333]) * 100
dbpedia_single = 0.978186 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.8, dbpedia_20_50, width = 0.8, label = '20 / 50', color = 'tab:orange')
ax.bar(num_workers, dbpedia_10_100, width = 0.8, label = '10 / 100', color = 'tab:green')
ax.bar(num_workers + 0.8, dbpedia_baseline, width = 0.8, label = 'paragraphE', color = 'tab:brown')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('Number of workers')
ax.set_ylabel('Accuracy (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 101, 10))
ax.set_xlim(2, 18)
ax.set_ylim(70, 100)

#plt.tight_layout()
plt.savefig('./bar_accuracy_transe_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestHITS dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([0.406083, 0.429, 0.42675, 0]) * 100
dbpedia_10_100 = np.array([0.385, 0.407417, 0.409917, 0]) * 100
dbpedia_baseline = np.array([0.059375, 0.059375, 0.058125, 0.06]) * 100
dbpedia_single = 0.391634 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.8, dbpedia_20_50, width = 0.8, label = '20 / 50', color = 'tab:orange')
ax.bar(num_workers, dbpedia_10_100, width = 0.8, label = '10 / 100', color = 'tab:green')
ax.bar(num_workers + 0.8, dbpedia_baseline, width = 0.8, label = 'paragraphE', color = 'tab:brown')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestHITS (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 100, 10))
ax.set_xlim(2, 18)
ax.set_ylim(0, 48)

#plt.tight_layout()
plt.savefig('./bar_besthit_transe_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestMRR dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([0.191462, 0.204526, 0.203386, 0])
dbpedia_10_100 = np.array([0.183429, 0.193519, 0.193931, 0])
dbpedia_baseline = np.array([0.0253055, 0.00608333, 0.0258687, 81597.8])
dbpedia_single = 0.193396

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.8, dbpedia_20_50, width = 0.8, label = '20 / 50', color = 'tab:orange')
ax.bar(num_workers, dbpedia_10_100, width = 0.8, label = '10 / 100', color = 'tab:green')
ax.bar(num_workers + 0.8, dbpedia_baseline, width = 0.8, label = 'paragraphE', color = 'tab:brown')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestMRR')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 0.41, 0.05))
ax.set_xlim(2, 18)
ax.set_ylim(0, 0.23)

#lt.tight_layout()
plt.savefig('./bar_bestmrr_transe_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## transG

# %%
# legend
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([28685.89323, 22045.75395, 20997.27301, 0])
dbpedia_10_100 = np.array([27964.2355, 24360.88596, 19833.37536, 0])
dbpedia_single = 49228.5

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.5, dbpedia_20_50, width = 1, label = '20 / 50', color = 'tab:orange')
ax.bar(num_workers + 0.5, dbpedia_10_100, width = 1, label = '10 / 100', color = 'tab:green')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('FOR LEGEND')
ax.set_ylabel('DO NOT USE THIS GRAPH')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 4)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 60000, 10000))
ax.set_xlim(2, 18)
ax.set_ylim(0, 55000)

#plt.tight_layout()
plt.savefig('./bar_legend_3_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# train_time dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([28685.89323, 22045.75395, 20997.27301, 0])
dbpedia_10_100 = np.array([27964.2355, 24360.88596, 19833.37536, 0])
dbpedia_single = 49228.5

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.5, dbpedia_20_50, width = 1, label = '20 / 50', color = 'tab:orange')
ax.bar(num_workers + 0.5, dbpedia_10_100, width = 1, label = '10 / 100', color = 'tab:green')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('Number of workers')
ax.set_ylabel('Training time (s)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 60000, 10000))
ax.set_xlim(2, 18)
ax.set_ylim(0, 55000)

#plt.tight_layout()
plt.savefig('./bar_traintime_transg_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# accuracy dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([0.9755, 0.972583, 0.972625, 0]) * 100
dbpedia_10_100 = np.array([0.97275, 0.968833, 0.968667, 0]) * 100
dbpedia_single = 0.98446 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.5, dbpedia_20_50, width = 1, label = '20 / 50', color = 'tab:orange')
ax.bar(num_workers + 0.5, dbpedia_10_100, width = 1, label = '10 / 100', color = 'tab:green')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('Number of workers')
ax.set_ylabel('Accuracy (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 101, 10))
ax.set_xlim(2, 18)
ax.set_ylim(70, 100)

#plt.tight_layout()
plt.savefig('./bar_accuracy_transg_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestHITS dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([0.415083, 0.440583, 0.450083, 0]) * 100
dbpedia_10_100 = np.array([0.38225, 0.402667, 0.41925, 0]) * 100
dbpedia_single = 0.395884 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.5, dbpedia_20_50, width = 1, label = '20 / 50', color = 'tab:orange')
ax.bar(num_workers + 0.5, dbpedia_10_100, width = 1, label = '10 / 100', color = 'tab:green')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestHITS (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 100, 10))
ax.set_xlim(2, 18)
ax.set_ylim(0, 50)

#plt.tight_layout()
plt.savefig('./bar_besthit_transg_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestMRR dbpedia
num_workers = np.array([4, 8, 12, 16])

dbpedia_20_50 = np.array([0.204896, 0.217871, 0.225431, 0])
dbpedia_10_100 = np.array([0.190695, 0.204094, 0.208206, 0])
dbpedia_single = 0.199667

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.5, dbpedia_20_50, width = 1, label = '20 / 50', color = 'tab:orange')
ax.bar(num_workers + 0.5, dbpedia_10_100, width = 1, label = '10 / 100', color = 'tab:green')
ax.plot([0, 20], [dbpedia_single, dbpedia_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('Number of workers')
ax.set_ylabel('BestMRR')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 0.41, 0.05))
ax.set_xlim(2, 18)
ax.set_ylim(0, 0.25)

#plt.tight_layout()
plt.savefig('./bar_bestmrr_transg_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()
