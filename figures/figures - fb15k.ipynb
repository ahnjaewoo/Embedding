# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr
import matplotlib.dates as mdates

# %matplotlib inline
plt.rcParams['text.latex.unicode'] = True
#plt.rcParams["font.family"] = 'Times New Roman'
plt.rcParams["font.size"] = 36

# %% [markdown]
# ## transE

# %%
# legend
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([371.7106439, 231.1742361, 176.2731587, 145.1070659])
fb15k_20_50 = np.array([392.5137885, 225.3250103, 167.8436638, 140.2183027])
fb15k_10_100 = np.array([416.9260891, 213.7487289, 155.6902227, 128.3966141])
fb15k_5_200 = np.array([466.0917256, 233.436649, 165.5002719, 131.7346193])
fb15k_5_100 = np.array([237.3625335, 126.2001934, 87.70242923, 69.98073341])
fb15k_baseline = np.array([665.615, 358.186, 241.745, 190.474])
fb15k_single = 528.13

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.625, fb15k_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.375, fb15k_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.125, fb15k_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.125, fb15k_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.375, fb15k_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.bar(num_workers +  0.625, fb15k_baseline, width = 0.25, label = 'ParaGraphE', color = '#A5A5A5')
ax.plot([0, 10], [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('FOR LEGEND')
ax.set_ylabel('DO NOT USE THIS GRAPH')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 4)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 700, 150))
ax.set_xlim(1, 9)
ax.set_ylim(0, 700)

#plt.tight_layout()
plt.savefig('./bar_legend_7_fbwn.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# train_time fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([371.7106439, 231.1742361, 176.2731587, 145.1070659])
fb15k_20_50 = np.array([392.5137885, 225.3250103, 167.8436638, 140.2183027])
fb15k_10_100 = np.array([416.9260891, 213.7487289, 155.6902227, 128.3966141])
fb15k_5_200 = np.array([466.0917256, 233.436649, 165.5002719, 131.7346193])
fb15k_5_100 = np.array([237.3625335, 126.2001934, 87.70242923, 69.98073341])
fb15k_baseline = np.array([665.615, 358.186, 241.745, 190.474])
fb15k_single = 528.13

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.625, fb15k_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.375, fb15k_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.125, fb15k_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.125, fb15k_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.375, fb15k_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.bar(num_workers +  0.625, fb15k_baseline, width = 0.25, label = 'paragraphE', color = '#A5A5A5')
ax.plot([0, 10], [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 700, 150))
ax.set_xlim(1, 9)
ax.set_ylim(0, 700)

ax.set_yticklabels(['{:,}'.format(v) + 's' for v in range(0, 700, 150)])

#plt.tight_layout()
plt.savefig('./bar_traintime_transe_fb15k.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# accuracy fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.977095, 0.97437, 0.974192, 0.972652]) * 100
fb15k_20_50 = np.array([0.977248, 0.974311, 0.972186, 0.972626]) * 100
fb15k_10_100 = np.array([0.975639, 0.970239, 0.968428, 0.966396]) * 100
fb15k_5_200 = np.array([0.970341, 0.963595, 0.957915, 0.955452]) * 100
fb15k_5_100 = np.array([0.97073, 0.962359, 0.959388, 0.957213]) * 100
fb15k_baseline = np.array([0.964077, 0.964001, 0.963798, 0.96472]) * 100
fb15k_single = 0.980591 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.625, fb15k_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.375, fb15k_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.125, fb15k_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.125, fb15k_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.375, fb15k_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.bar(num_workers +  0.625, fb15k_baseline, width = 0.25, label = 'paragraphE', color = '#A5A5A5')
ax.plot([0, 10], [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 101, 5))
ax.set_xlim(1, 9)
ax.set_ylim(85, 101)

ax.set_yticklabels([str(v) + '%' for v in range(0, 101, 5)])
ax.yaxis.set_label_position('right')
ax.yaxis.tick_right()

#plt.tight_layout()
plt.savefig('./bar_accuracy_transe_fb15k.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# BestHITS fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.612551, 0.610672, 0.608776, 0.605966]) * 100
fb15k_20_50 = np.array([0.611992, 0.607049, 0.609368, 0.604815]) * 100
fb15k_10_100 = np.array([0.601513, 0.597163, 0.595639, 0.59073]) * 100
fb15k_5_200 = np.array([0.584145, 0.572684, 0.577153, 0.569653]) * 100
fb15k_5_100 = np.array([0.584094, 0.565117, 0.569687, 0.562425]) * 100
fb15k_baseline = np.array([0.453124, 0.454817, 0.451601, 0.455807]) * 100
fb15k_single = 0.604635 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.625, fb15k_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.375, fb15k_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.125, fb15k_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.125, fb15k_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.375, fb15k_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.bar(num_workers +  0.625, fb15k_baseline, width = 0.25, label = 'paragraphE', color = '#A5A5A5')
ax.plot([0, 10], [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 100, 10))
ax.set_xlim(1, 9)
ax.set_ylim(0, 65)

ax.set_yticklabels([str(v) + '%' for v in range(0, 101, 10)])

#plt.tight_layout()
plt.savefig('./bar_besthit_transe_fb15k.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# BestMRR fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.38559, 0.388661, 0.387982, 0.386387])
fb15k_20_50 = np.array([0.387539, 0.387854, 0.390187, 0.386864])
fb15k_10_100 = np.array([0.379935, 0.376737, 0.382003, 0.375909])
fb15k_5_200 = np.array([0.360978, 0.356745, 0.360779, 0.358358])
fb15k_5_100 = np.array([0.362007, 0.35032, 0.352423, 0.351102])
fb15k_baseline = np.array([0.241504, 0.244103, 0.241382, 0.244395])
fb15k_single = 0.37957

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.625, fb15k_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.375, fb15k_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers - 0.125, fb15k_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.125, fb15k_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.375, fb15k_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.bar(num_workers +  0.625, fb15k_baseline, width = 0.25, label = 'paragraphE', color = '#A5A5A5')
ax.plot([0, 10], [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 0.41, 0.1))
ax.set_xlim(1, 9)
ax.set_ylim(0, 0.43)

ax.yaxis.set_label_position('right')
ax.yaxis.tick_right()

#lt.tight_layout()
plt.savefig('./bar_bestmrr_transe_fb15k.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## transG

# %%
# legend
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([4096.366736, 1427.424916, 1018.740698, 796.6694129])
fb15k_20_50 = np.array([3123.473288, 1492.162466, 1067.502415, 842.3042937])
fb15k_10_100 = np.array([3248.495131, 1671.48717, 1183.685035, 1337.076569])
fb15k_5_200 = np.array([4009.90163, 2055.571171, 1373.671845, 1566.660069])
fb15k_5_100 = np.array([1928.755998, 1011.86134, 675.9950464, 720.6539941])
fb15k_single = 2050.53

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.50, fb15k_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.25, fb15k_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, fb15k_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.25, fb15k_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.50, fb15k_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.plot([0, 10], [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xlabel('FOR LEGEND')
ax.set_ylabel('DO NOT USE THIS GRAPH')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 3)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 5000, 1000))
ax.set_xlim(1, 9)
ax.set_ylim(0, 4500)

#plt.tight_layout()
plt.savefig('./bar_legend_6_fbwn.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# train_time fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([4096.366736, 1427.424916, 1018.740698, 796.6694129])
fb15k_20_50 = np.array([3123.473288, 1492.162466, 1067.502415, 842.3042937])
fb15k_10_100 = np.array([3248.495131, 1671.48717, 1183.685035, 1337.076569])
fb15k_5_200 = np.array([4009.90163, 2055.571171, 1373.671845, 1566.660069])
fb15k_5_100 = np.array([1928.755998, 1011.86134, 675.9950464, 720.6539941])
fb15k_single = 2050.53

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.50, fb15k_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.25, fb15k_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, fb15k_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.25, fb15k_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.50, fb15k_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.plot([0, 10], [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 5000, 1000))
ax.set_xlim(1, 9)
ax.set_ylim(0, 4500)

ax.set_yticklabels(['{:,}'.format(v) + 's' for v in range(0, 5000, 1000)])

#plt.tight_layout()
plt.savefig('./bar_traintime_transg_fb15k.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# accuracy fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.978111, 0.975369, 0.974751, 0.9736]) * 100
fb15k_20_50 = np.array([0.977832, 0.975462, 0.973092, 0.973845]) * 100
fb15k_10_100 = np.array([0.975648, 0.972313, 0.968682, 0.968885]) * 100
fb15k_5_200 = np.array([0.969791, 0.963544, 0.959896, 0.957331]) * 100
fb15k_5_100 = np.array([0.969824, 0.963163, 0.959295, 0.958279]) * 100
fb15k_single = 0.980101 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.50, fb15k_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.25, fb15k_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, fb15k_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.25, fb15k_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.50, fb15k_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.plot([0, 10], [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 101, 5))
ax.set_xlim(1, 9)
ax.set_ylim(85, 101)

ax.set_yticklabels([str(v) + '%' for v in range(0, 101, 5)])
ax.yaxis.set_label_position('right')
ax.yaxis.tick_right()

#plt.tight_layout()
plt.savefig('./bar_accuracy_transg_fb15k.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# BestHITS fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.611755, 0.612179, 0.610046, 0.605712]) * 100
fb15k_20_50 = np.array([0.606474, 0.60192, 0.599821, 0.596943]) * 100
fb15k_10_100 = np.array([0.593591, 0.586278, 0.582841, 0.580115]) * 100
fb15k_5_200 = np.array([0.567013, 0.564152, 0.559886, 0.563119]) * 100
fb15k_5_100 = np.array([0.571211, 0.549305, 0.563948, 0.552132]) * 100
fb15k_single = 0.602299 * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.50, fb15k_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.25, fb15k_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, fb15k_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.25, fb15k_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.50, fb15k_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.plot([0, 10], [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 101, 10))
ax.set_xlim(1, 9)
ax.set_ylim(0, 65)

ax.set_yticklabels([str(v) + '%' for v in range(0, 101, 10)])

#plt.tight_layout()
plt.savefig('./bar_besthit_transg_fb15k.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# BestMRR fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([0.387958, 0.39318, 0.391538, 0.393428])
fb15k_20_50 = np.array([0.384406, 0.38473, 0.383829, 0.384234])
fb15k_10_100 = np.array([0.375834, 0.373457, 0.374833, 0.373502])
fb15k_5_200 = np.array([0.343728, 0.352741, 0.351783, 0.355968])
fb15k_5_100 = np.array([0.348981, 0.344796, 0.350339, 0.345374])
fb15k_single = 0.379378

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.50, fb15k_25_40, width = 0.25, label = '25 / 40', color = '#3B65A9')
ax.bar(num_workers - 0.25, fb15k_20_50, width = 0.25, label = '20 / 50', color = '#D4722F')
ax.bar(num_workers, fb15k_10_100, width = 0.25, label = '10 / 100', color = '#70AD47')
ax.bar(num_workers + 0.25, fb15k_5_200, width = 0.25, label = '5 / 200', color = '#E5AE16')
ax.bar(num_workers + 0.50, fb15k_5_100, width = 0.25, label = '5 / 100', color = '#8957A1')
ax.plot([0, 10], [fb15k_single, fb15k_single], c = 'k', linestyle = '--', label = 'original', lw = 4, zorder = -1)
ax.set_xticks(num_workers)
ax.set_yticks(np.arange(0, 0.41, 0.1))
ax.set_xlim(1, 9)
ax.set_ylim(0, 0.43)

ax.yaxis.set_label_position('right')
ax.yaxis.tick_right()

#plt.tight_layout()
plt.savefig('./bar_bestmrr_transg_fb15k.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Speed Up

# %%
# train_time fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([371.7106439, 231.1742361, 176.2731587, 145.1070659])
fb15k_20_50 = np.array([392.5137885, 225.3250103, 167.8436638, 140.2183027])
fb15k_10_100 = np.array([416.9260891, 213.7487289, 155.6902227, 128.3966141])
fb15k_5_200 = np.array([466.0917256, 233.436649, 165.5002719, 131.7346193])
fb15k_5_100 = np.array([237.3625335, 126.2001934, 87.70242923, 69.98073341])
fb15k_baseline = np.array([665.615, 358.186, 241.745, 190.474])
fb15k_single = 528.13

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.plot(num_workers, fb15k_single / fb15k_25_40, marker = 'D', linestyle = '-', label = '25 / 40',
        lw = 4, markersize = 16, color = '#3B65A9')
ax.plot(num_workers, fb15k_single / fb15k_20_50, marker = 'o', linestyle = '-', label = '20 / 50',
        lw = 4, markersize = 16, color = '#D4722F')
ax.plot(num_workers, fb15k_single / fb15k_10_100, marker = 'v', linestyle = '-', label = '10 / 100',
        lw = 4, markersize = 16, color = '#70AD47')
ax.plot(num_workers, fb15k_single / fb15k_5_200, marker = '^', linestyle = '-', label = '5 / 200',
        lw = 4, markersize = 16, color = '#E5AE16')
ax.plot(num_workers, fb15k_single / fb15k_5_100, marker = '*', linestyle = '-', label = '5 / 100',
        lw = 4, markersize = 16, color = '#8957A1')
ax.plot(num_workers, fb15k_single / fb15k_baseline, marker = 's', linestyle = '-', label = 'paragraphE',
        lw = 4, markersize = 16, color = '#A5A5A5')
ax.plot([1, 8], [1, 8], c = 'k', linestyle = '--', label = 'Ideal', lw = 4, zorder = -1)
ax.set_xlim(0, 9)
ax.set_ylim(0, 9)
ax.set_xticks(num_workers)
ax.set_yticks(num_workers)
ax.set_xlabel('Number of workers')
ax.set_ylabel('Speed up')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 4)

#plt.tight_layout()
plt.savefig('./line_speedup_transe_fb15k.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# train_time fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([4096.366736, 1427.424916, 1018.740698, 796.6694129])
fb15k_20_50 = np.array([3123.473288, 1492.162466, 1067.502415, 842.3042937])
fb15k_10_100 = np.array([3248.495131, 1671.48717, 1183.685035, 1337.076569])
fb15k_5_200 = np.array([4009.90163, 2055.571171, 1373.671845, 1566.660069])
fb15k_5_100 = np.array([1928.755998, 1011.86134, 675.9950464, 720.6539941])
fb15k_single = 2050.53

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.plot(num_workers, fb15k_single / fb15k_25_40, marker = 'D', linestyle = '-', label = '25 / 40',
        lw = 4, markersize = 16, color = '#3B65A9')
ax.plot(num_workers, fb15k_single / fb15k_20_50, marker = 'o', linestyle = '-', label = '20 / 50',
        lw = 4, markersize = 16, color = '#D4722F')
ax.plot(num_workers, fb15k_single / fb15k_10_100, marker = 'v', linestyle = '-', label = '10 / 100',
        lw = 4, markersize = 16, color = '#70AD47')
ax.plot(num_workers, fb15k_single / fb15k_5_200, marker = '^', linestyle = '-', label = '5 / 200',
        lw = 4, markersize = 16, color = '#E5AE16')
ax.plot(num_workers, fb15k_single / fb15k_5_100, marker = '*', linestyle = '-', label = '5 / 100',
        lw = 4, markersize = 16, color = '#8957A1')
ax.plot([1, 8], [1, 8], c = 'k', linestyle = '--', label = 'Ideal', lw = 4, zorder = -1)
ax.set_xlim(0, 9)
ax.set_ylim(0, 9)
ax.set_xticks(num_workers)
ax.set_yticks(num_workers)
ax.set_xlabel('Number of workers')
ax.set_ylabel('Speed up')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 3)

#plt.tight_layout()
plt.savefig('./line_speedup_transg_fb15k.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()

# %%
# train_time fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_25_40 = np.array([371.7106439, 231.1742361, 176.2731587, 145.1070659])
fb15k_20_50 = np.array([392.5137885, 225.3250103, 167.8436638, 140.2183027])
fb15k_10_100 = np.array([416.9260891, 213.7487289, 155.6902227, 128.3966141])
fb15k_5_200 = np.array([466.0917256, 233.436649, 165.5002719, 131.7346193])
fb15k_5_100 = np.array([237.3625335, 126.2001934, 87.70242923, 69.98073341])
fb15k_baseline = np.array([665.615, 358.186, 241.745, 190.474])
fb15k_single = 528.13

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.plot(num_workers, fb15k_single / fb15k_25_40, marker = 'D', linestyle = '-', label = '25 / 40',
        lw = 4, markersize = 16, color = '#3B65A9')
ax.plot(num_workers, fb15k_single / fb15k_20_50, marker = 'o', linestyle = '-', label = '20 / 50',
        lw = 4, markersize = 16, color = '#D4722F')
ax.plot(num_workers, fb15k_single / fb15k_10_100, marker = 'v', linestyle = '-', label = '10 / 100',
        lw = 4, markersize = 16, color = '#70AD47')
ax.plot(num_workers, fb15k_single / fb15k_5_200, marker = '^', linestyle = '-', label = '5 / 200',
        lw = 4, markersize = 16, color = '#E5AE16')
ax.plot(num_workers, fb15k_single / fb15k_5_100, marker = '*', linestyle = '-', label = '5 / 100',
        lw = 4, markersize = 16, color = '#8957A1')
ax.plot(num_workers, fb15k_single / fb15k_baseline, marker = 's', linestyle = '-', label = 'paragraphE',
        lw = 4, markersize = 16, color = '#A5A5A5')
ax.plot([1, 8], [1, 8], c = 'k', linestyle = '--', label = 'Ideal', lw = 4, zorder = -1)
ax.set_xlim(0, 9)
ax.set_ylim(0, 9)
ax.set_xticks(num_workers)
ax.set_yticks(num_workers)
ax.set_xlabel('Number of workers')
ax.set_ylabel('Speed up')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (1.3, 1), fancybox = True, ncol = 1)

#plt.tight_layout()
plt.savefig('./line_speedup_transe_fb15k_vertical.pdf', dpi = 300, quality = 100, bbox_inches = 'tight')
plt.show()
