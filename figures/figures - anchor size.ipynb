# %%
import numpy as np
import networkx as nx
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr
import matplotlib.dates as mdates

# %matplotlib inline
plt.rcParams['text.latex.unicode'] = True
#plt.rcParams["font.family"] = 'Times New Roman'
plt.rcParams["font.size"] = 36

# %% [markdown]
# ## fb15k

# %%
# legend
num_workers = np.array([2, 4, 6, 8])

fb15k_transe = np.array([106.3692226, 117.4969349, 133.5354426, 144.978385])
fb15k_transg = np.array([625.8676395, 691.0145142, 788.316916, 813.0740493])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.35, fb15k_transe, width = 0.7, label = 'transE', color = '#CFF67B')
ax.bar(num_workers + 0.35, fb15k_transg, width = 0.7, label = 'transG', color = '#FFA726')
ax.set_xlabel('FOR LEGEND')
ax.set_ylabel('DO NOT USE THIS GRAPH')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 4)
ax.set_xticks(num_workers)
ax.set_xticklabels(['10', '100', '1000', '2000'])
ax.set_yticks(np.arange(0, 800, 150))
ax.set_xlim(1, 9)
ax.set_ylim(0, 850)

#plt.tight_layout()
plt.savefig('./bar_legend_2_anchorsize.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# train_time fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_transe = np.array([106.3692226, 117.4969349, 133.5354426, 144.978385])
fb15k_transg = np.array([625.8676395, 691.0145142, 788.316916, 813.0740493])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.35, fb15k_transe, width = 0.7, label = 'transE', color = '#CFF67B')
ax.bar(num_workers + 0.35, fb15k_transg, width = 0.7, label = 'transG', color = '#FFA726')
ax.set_xlabel('Number of anchors')
ax.set_ylabel('Training time (s)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['10', '100', '1000', '2000'])
ax.set_yticks(np.arange(0, 760, 150))
ax.set_xlim(1, 5)
ax.set_ylim(0, 750)

#plt.tight_layout()
plt.savefig('./anchorsize_traintime_fb15k.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# accuracy fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_transe = np.array([0.952794, 0.958228, 0.96715, 0.967251]) * 100
fb15k_transg = np.array([0.956205, 0.958211, 0.966786, 0.969951]) * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.35, fb15k_transe, width = 0.7, label = 'transE', color = '#CFF67B')
ax.bar(num_workers + 0.35, fb15k_transg, width = 0.7, label = 'transG', color = '#FFA726')
ax.set_xlabel('Number of anchors')
ax.set_ylabel('Accuracy (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['10', '100', '1000', '2000'])
ax.set_yticks(np.arange(0, 101, 10))
ax.set_xlim(1, 9)
ax.set_ylim(75, 100)

#plt.tight_layout()
plt.savefig('./anchorsize_accuracy_fb15k.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestHITS fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_transe = np.array([0.576696, 0.585279, 0.588377, 0.580928]) * 100
fb15k_transg = np.array([0.574106, 0.579201, 0.585736, 0.575172]) * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.35, fb15k_transe, width = 0.7, label = 'transE', color = '#CFF67B')
ax.bar(num_workers + 0.35, fb15k_transg, width = 0.7, label = 'transG', color = '#FFA726')
ax.set_xlabel('Number of anchors')
ax.set_ylabel('BestHITS (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['10', '100', '1000', '2000'])
ax.set_yticks(np.arange(0, 100, 10))
ax.set_xlim(1, 9)
ax.set_ylim(0, 65)

#plt.tight_layout()
plt.savefig('./anchorsize_besthit_fb15k.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestMRR fb15k
num_workers = np.array([2, 4, 6, 8])

fb15k_transe = np.array([0.374266, 0.380307, 0.3779, 0.369169])
fb15k_transg = np.array([0.380807, 0.376538, 0.3756, 0.370599])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.35, fb15k_transe, width = 0.7, label = 'transE', color = '#CFF67B')
ax.bar(num_workers + 0.35, fb15k_transg, width = 0.7, label = 'transG', color = '#FFA726')
ax.set_xlabel('Number of anchors')
ax.set_ylabel('BestMRR')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['10', '100', '1000', '2000'])
ax.set_yticks(np.arange(0, 0.41, 0.1))
ax.set_xlim(1, 9)
ax.set_ylim(0, 0.41)

#lt.tight_layout()
plt.savefig('./anchorsize_bestmrr_fb15k.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## wn18

# %%
# train_time wn18
num_workers = np.array([2, 4, 6, 8])

wn18_transe = np.array([82.4858425, 94.18304886, 83.17734275, 87.02773712])
wn18_transg = np.array([361.5554885, 380.8938554, 370.6907581, 384.7812616])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.35, wn18_transe, width = 0.7, label = 'transE', color = '#CFF67B')
ax.bar(num_workers + 0.35, wn18_transg, width = 0.7, label = 'transG', color = '#FFA726')
ax.set_xlabel('Number of anchors')
ax.set_ylabel('Training time (s)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['10', '100', '1000', '5000'])
ax.set_yticks(np.arange(0, 800, 100))
ax.set_xlim(1, 9)
ax.set_ylim(0, 450)

#plt.tight_layout()
plt.savefig('./anchorsize_traintime_wn18.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# accuracy wn18
num_workers = np.array([2, 4, 6, 8])

wn18_transe = np.array([0.9605, 0.9653, 0.9648, 0.9621]) * 100
wn18_transg = np.array([0.9654, 0.9681, 0.9707, 0.9668]) * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.35, wn18_transe, width = 0.7, label = 'transE', color = '#CFF67B')
ax.bar(num_workers + 0.35, wn18_transg, width = 0.7, label = 'transG', color = '#FFA726')
ax.set_xlabel('Number of anchors')
ax.set_ylabel('Accuracy (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['10', '100', '1000', '5000'])
ax.set_yticks(np.arange(0, 101, 10))
ax.set_xlim(1, 9)
ax.set_ylim(75, 100)

#plt.tight_layout()
plt.savefig('./anchorsize_accuracy_wn18.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestHITS wn18
num_workers = np.array([2, 4, 6, 8])

wn18_transe = np.array([0.8466, 0.8634, 0.8748, 0.855]) * 100
wn18_transg = np.array([0.8874, 0.8946, 0.908, 0.9]) * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.35, wn18_transe, width = 0.7, label = 'transE', color = '#CFF67B')
ax.bar(num_workers + 0.35, wn18_transg, width = 0.7, label = 'transG', color = '#FFA726')
ax.set_xlabel('Number of anchors')
ax.set_ylabel('BestHITS (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['10', '100', '1000', '5000'])
ax.set_yticks(np.arange(0, 100, 15))
ax.set_xlim(1, 9)
ax.set_ylim(0, 95)

#plt.tight_layout()
plt.savefig('./anchorsize_besthit_wn18.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestMRR wn18
num_workers = np.array([2, 4, 6, 8])

wn18_transe = np.array([0.451914, 0.459102, 0.476559, 0.464631])
wn18_transg = np.array([0.507539, 0.545104, 0.509793, 0.442168])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.35, wn18_transe, width = 0.7, label = 'transE', color = '#CFF67B')
ax.bar(num_workers + 0.35, wn18_transg, width = 0.7, label = 'transG', color = '#FFA726')
ax.set_xlabel('Number of anchors')
ax.set_ylabel('BestMRR')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['10', '100', '1000', '5000'])
ax.set_yticks(np.arange(0, 0.61, 0.1))
ax.set_xlim(1, 9)
ax.set_ylim(0, 0.60)

#lt.tight_layout()
plt.savefig('./anchorsize_bestmrr_wn18.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## dbpedia

# %%
# train_time dbpedia
num_workers = np.array([2, 4, 6, 8])

dbpedia_transe = np.array([3109.032231, 3293.660156, 3457.155755, 6701.179072])
dbpedia_transg = np.array([8254.706643, 8567.371015, 8377.860229, 11844.25019])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.35, dbpedia_transe, width = 0.7, label = 'transE', color = '#CFF67B')
ax.bar(num_workers + 0.35, dbpedia_transg, width = 0.7, label = 'transG', color = '#FFA726')
ax.set_xlabel('Number of anchors')
ax.set_ylabel('Training time (s)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['10', '100', '1000', '10000'])
ax.set_yticks(np.arange(0, 14000, 2000))
ax.set_xlim(1, 9)
ax.set_ylim(0, 12500)

#plt.tight_layout()
plt.savefig('./anchorsize_traintime_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# accuracy dbpedia
num_workers = np.array([2, 4, 6, 8])

dbpedia_transe = np.array([0.95725, 0.959542, 0.962375, 0.965625]) * 100
dbpedia_transg = np.array([0.960583, 0.96225, 0.962083, 0.963917]) * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.35, dbpedia_transe, width = 0.7, label = 'transE', color = '#CFF67B')
ax.bar(num_workers + 0.35, dbpedia_transg, width = 0.7, label = 'transG', color = '#FFA726')
ax.set_xlabel('Number of anchors')
ax.set_ylabel('Accuracy (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['10', '100', '1000', '10000'])
ax.set_yticks(np.arange(0, 101, 10))
ax.set_xlim(1, 9)
ax.set_ylim(75, 100)

#plt.tight_layout()
plt.savefig('./anchorsize_accuracy_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestHITS dbpedia
num_workers = np.array([2, 4, 6, 8])

dbpedia_transe = np.array([0.353833, 0.353583, 0.364083, 0.409917]) * 100
dbpedia_transg = np.array([0.349167, 0.361417, 0.37375, 0.397833]) * 100

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.35, dbpedia_transe, width = 0.7, label = 'transE', color = '#CFF67B')
ax.bar(num_workers + 0.35, dbpedia_transg, width = 0.7, label = 'transG', color = '#FFA726')
ax.set_xlabel('Number of anchors')
ax.set_ylabel('BestHITS (%)')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['10', '100', '1000', '10000'])
ax.set_yticks(np.arange(0, 100, 10))
ax.set_xlim(1, 9)
ax.set_ylim(0, 45)

#plt.tight_layout()
plt.savefig('./anchorsize_besthit_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()

# %%
# BestMRR dbpedia
num_workers = np.array([2, 4, 6, 8])

dbpedia_transe = np.array([0.167917, 0.167374, 0.171113, 0.193931])
dbpedia_transg = np.array([0.174502, 0.177083, 0.185348, 0.195869])

fig, ax = plt.subplots(1, 1, figsize = (12, 9))

ax.bar(num_workers - 0.35, dbpedia_transe, width = 0.7, label = 'transE', color = '#CFF67B')
ax.bar(num_workers + 0.35, dbpedia_transg, width = 0.7, label = 'transG', color = '#FFA726')
ax.set_xlabel('Number of anchors')
ax.set_ylabel('BestMRR')
legend = ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.18), fancybox = True, ncol = 2)
ax.set_xticks(num_workers)
ax.set_xticklabels(['10', '100', '1000', '10000'])
ax.set_yticks(np.arange(0, 0.61, 0.05))
ax.set_xlim(1, 9)
ax.set_ylim(0, 0.21)

#lt.tight_layout()
plt.savefig('./anchorsize_bestmrr_dbpedia.pdf', dpi = 300, quality = 100, bbox_extra_artists = (legend,), bbox_inches = 'tight')
plt.show()
